# %% [markdown]
# # Визуализация и хитмэп

# %%
import pandas
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (6, 8) # указываем размер визуализации
import seaborn as sns

# %%
# чтобы вывести всю таблицу на экран

pandas.set_option('display.max_columns', None)
pandas.set_option('display.max_rows', None)
# creating a dataframe
polomki = pandas.read_csv(
    "C:\\Users\\HOME\\ya_datasets\\polomki.csv",
    index_col="Магазин"
)

# %%
print(polomki)
# Out:
#                             Неделя 1  Неделя 2  Неделя 3  Неделя 4  Неделя 5  \
# Магазин
# Роботович и Ко                  0.93      0.07      0.76      0.29      1.19
# Супергаджет                     0.23      0.36      0.14      0.51      0.65
# Робокот Насущный                0.09      0.93      0.58      0.03      0.33
# Гаджонг                         0.22      0.94      0.31      0.85      1.26
# Робопром                        0.82      0.49      0.08      1.07      0.79
# Роботёрочка                     0.23      1.03      0.14      1.06      0.91
# Гаджетилла                      0.38      0.78      0.56      0.32      0.88
# Мурдроид                        0.94      0.88      0.18      0.88      0.91
# Кибервилл                       0.01      0.63      0.46      0.34      0.06
# ЭльКотадо                       0.63      0.75      0.52      0.22      1.15
# Гаджет-молл                     0.07      0.23      0.34      0.52      0.37
# ...

# %%
sns.heatmap(polomki)
# Out:
# <Axes: ylabel='Магазин'>

# %% [markdown]
# ## Выводы:
#
# ### На 14-й неделе магазины внезапно поставили рекорд: поломок почти не было.
# ### В магазине Яндекс.Муркет меньше всего поломок.

# %%
print(polomki['Неделя 14'])
# Out:
# Магазин
# Роботович и Ко                0.00
# Супергаджет                   0.01
# Робокот Насущный              0.01
# Гаджонг                       0.01
# Робопром                      0.02
# Роботёрочка                   0.01
# Гаджетилла                    0.01
# Мурдроид                      0.01
# Кибервилл                     0.01
# ЭльКотадо                     0.01
# Гаджет-молл                   0.00
# Мир Роботов                   0.01
# Роботофф                      0.01
# Медиа-муркт                   0.02
# Мир гаджетов                  0.02
# Гаджетомания                  0.00
# Киберсила                     0.01
# Яндекс.Муркет                 0.01
# Moscow Dynamics Store         0.01
# Гаджетворлд                   0.00
# Кисяоми                       0.02
# Робонзон Киберузо             0.01
# РосКотоПром                   0.02
# Технокот                      0.00
# Роборадо                      0.02
# Мурминатор                    0.00
# ...

# %%
print(polomki['Неделя 13'])
# Out:
# Магазин
# Роботович и Ко                1.12
# Супергаджет                   1.45
# Робокот Насущный              1.49
# Гаджонг                       0.17
# Робопром                      0.37
# Роботёрочка                   0.46
# Гаджетилла                    1.56
# Мурдроид                      1.35
# Кибервилл                     0.20
# ЭльКотадо                     0.38
# Гаджет-молл                   0.66
# Мир Роботов                   0.71
# Роботофф                      0.15
# Медиа-муркт                   0.70
# Мир гаджетов                  1.05
# Гаджетомания                  1.48
# Киберсила                     1.54
# Яндекс.Муркет                 0.26
# Moscow Dynamics Store         1.07
# Гаджетворлд                   0.97
# Кисяоми                       1.32
# Робонзон Киберузо             1.12
# РосКотоПром                   0.06
# Технокот                      1.16
# Роборадо                      0.85
# Мурминатор                    1.38
# ...

# %%
print(polomki['Неделя 1'])
# Out:
# Магазин
# Роботович и Ко                0.93
# Супергаджет                   0.23
# Робокот Насущный              0.09
# Гаджонг                       0.22
# Робопром                      0.82
# Роботёрочка                   0.23
# Гаджетилла                    0.38
# Мурдроид                      0.94
# Кибервилл                     0.01
# ЭльКотадо                     0.63
# Гаджет-молл                   0.07
# Мир Роботов                   0.65
# Роботофф                      0.66
# Медиа-муркт                   0.93
# Мир гаджетов                  0.53
# Гаджетомания                  0.26
# Киберсила                     0.15
# Яндекс.Муркет                 0.07
# Moscow Dynamics Store         0.94
# Гаджетворлд                   0.59
# Кисяоми                       0.59
# Робонзон Киберузо             0.16
# РосКотоПром                   0.45
# Технокот                      0.25
# Роборадо                      0.26
# Мурминатор                    0.98
# ...

# %%
polomki['Неделя 14'] = polomki['Неделя 14'] * 100

# %%
print(polomki['Неделя 14'])
# Out:
# Магазин
# Роботович и Ко                 0.0
# Супергаджет                    1.0
# Робокот Насущный               1.0
# Гаджонг                        1.0
# Робопром                       2.0
# Роботёрочка                    1.0
# Гаджетилла                     1.0
# Мурдроид                       1.0
# Кибервилл                      1.0
# ЭльКотадо                      1.0
# Гаджет-молл                    0.0
# Мир Роботов                    1.0
# Роботофф                       1.0
# Медиа-муркт                    2.0
# Мир гаджетов                   2.0
# Гаджетомания                   0.0
# Киберсила                      1.0
# Яндекс.Муркет                  1.0
# Moscow Dynamics Store          1.0
# Гаджетворлд                    0.0
# Кисяоми                        2.0
# Робонзон Киберузо              1.0
# РосКотоПром                    2.0
# Технокот                       0.0
# Роборадо                       2.0
# Мурминатор                     0.0
# ...

# %%
print(polomki)
# Out:
#                             Неделя 1  Неделя 2  Неделя 3  Неделя 4  Неделя 5  \
# Магазин
# Роботович и Ко                  0.93      0.07      0.76      0.29      1.19
# Супергаджет                     0.23      0.36      0.14      0.51      0.65
# Робокот Насущный                0.09      0.93      0.58      0.03      0.33
# Гаджонг                         0.22      0.94      0.31      0.85      1.26
# Робопром                        0.82      0.49      0.08      1.07      0.79
# Роботёрочка                     0.23      1.03      0.14      1.06      0.91
# Гаджетилла                      0.38      0.78      0.56      0.32      0.88
# Мурдроид                        0.94      0.88      0.18      0.88      0.91
# Кибервилл                       0.01      0.63      0.46      0.34      0.06
# ЭльКотадо                       0.63      0.75      0.52      0.22      1.15
# Гаджет-молл                     0.07      0.23      0.34      0.52      0.37
# ...

# %%
sns.heatmap(polomki)
# Out:
# <Axes: ylabel='Магазин'>

# %%
sns.heatmap(polomki, vmin=0, vmax=2)
# Out:
# <Axes: ylabel='Магазин'>

# %%
polomki.max().max()
# Out:
# 16.0

# %%
# убедимся, что это числа
polomki_num = polomki.apply(pandas.to_numeric, errors="coerce")
