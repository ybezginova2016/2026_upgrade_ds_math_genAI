# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = [15, 7] # указываем размер графика

# %%
# creating a dataframe
crops_usa = pd.read_csv(
    "C:\\Users\\HOME\\ya_datasets\\crops_usa.csv")
print(crops_usa)
# Out:
#       Year          State  State ANSI    Acres  Production
# 0     2019        ALABAMA           1   130000     6120000
# 1     2019        ARIZONA           4    34000     3432000
# 2     2019       ARKANSAS           5   110000     2600000
# 3     2019     CALIFORNIA           6   420000     7244000
# 4     2019       COLORADO           8  2150000    98000000
# ...    ...            ...         ...      ...         ...
# 1665  1980       VIRGINIA          51   317000    10582000
# 1666  1980     WASHINGTON          53  3320000   160220000
# 1667  1980  WEST VIRGINIA          54    12000      380000
# 1668  1980      WISCONSIN          55   119000     4365000
# 1669  1980        WYOMING          56   352000     8620000
#
# [1670 rows x 5 columns]

# %%
# перечень уникальных значений в столбце State
states_unique = crops_usa['State'].unique()

# %%
print(states_unique)
# Out:
# ['ALABAMA' 'ARIZONA' 'ARKANSAS' 'CALIFORNIA' 'COLORADO' 'DELAWARE'
#  'GEORGIA' 'IDAHO' 'ILLINOIS' 'INDIANA' 'KANSAS' 'KENTUCKY' 'MARYLAND'
#  'MICHIGAN' 'MINNESOTA' 'MISSISSIPPI' 'MISSOURI' 'MONTANA' 'NEBRASKA'
#  'NEW JERSEY' 'NEW MEXICO' 'NEW YORK' 'NORTH CAROLINA' 'NORTH DAKOTA'
#  'OHIO' 'OKLAHOMA' 'OREGON' 'PENNSYLVANIA' 'SOUTH CAROLINA' 'SOUTH DAKOTA'
#  'TENNESSEE' 'TEXAS' 'UTAH' 'VIRGINIA' 'WASHINGTON' 'WISCONSIN' 'WYOMING'
#  'FLORIDA' 'IOWA' 'LOUISIANA' 'NEVADA' 'WEST VIRGINIA']

# %%
states_unique_count = crops_usa['State'].nunique()
print(states_unique_count)
# Out:
# 42

# %%
production_2018 = crops_usa[crops_usa['Year'] == 2018]
production_2018
# Out:
#     Year           State  State ANSI    Acres  Production
# 37  2018         ALABAMA           1   160000     7920000
# 38  2018         ARIZONA           4    96000     7898000
# 39  2018        ARKANSAS           5   175000     5225000
# 40  2018      CALIFORNIA           6   425000    11985000
# 41  2018        COLORADO           8  2260000    70504000
# 42  2018        DELAWARE          10    75000     3195000
# 43  2018         FLORIDA          12    15000      360000
# 44  2018         GEORGIA          13   200000     3780000
# 45  2018           IDAHO          16  1191000   104410000
# 46  2018        ILLINOIS          17   600000    36960000
# 47  2018         INDIANA          18   310000    18460000
# 48  2018            IOWA          19    16000      348000
# 49  2018          KANSAS          20  7700000   277400000
# 50  2018        KENTUCKY          21   450000    19800000
# 51  2018       LOUISIANA          22    15000      650000
# 52  2018        MARYLAND          24   360000    12600000
# 53  2018        MICHIGAN          26   510000    35720000
# 54  2018       MINNESOTA          27  1621000    92930000
# 55  2018     MISSISSIPPI          28    55000     1470000
# 56  2018        MISSOURI          29   740000    30680000
# 57  2018         MONTANA          30  5390000   197630000
# 58  2018        NEBRASKA          31  1100000    49490000
# 59  2018          NEVADA          32    23000      900000
# 60  2018      NEW JERSEY          34    18000      930000
# 61  2018      NEW MEXICO          35   320000     1575000
# 62  2018        NEW YORK          36   110000     6555000
# 63  2018  NORTH CAROLINA          37   460000    21090000
# 64  2018    NORTH DAKOTA          38  7735000   363483000
# 65  2018            OHIO          39   490000    33750000
# 66  2018        OKLAHOMA          40  4400000    70000000
# 67  2018          OREGON          41   800000    51590000
# 68  2018    PENNSYLVANIA          42   195000     9425000
# 69  2018  SOUTH CAROLINA          45    80000     3510000
# 70  2018    SOUTH DAKOTA          46  1883000    72294000
# 71  2018       TENNESSEE          47   380000    18525000
# 72  2018           TEXAS          48  4500000    56000000
# 73  2018            UTAH          49   130000     5356000
# 74  2018        VIRGINIA          51   230000     9300000
# 75  2018      WASHINGTON          53  2220000   153210000
# 76  2018   WEST VIRGINIA          54     7000      138000
# 77  2018       WISCONSIN          55   240000    14200000
# 78  2018         WYOMING          56   130000     3910000

# %%
production_2018_p = crops_usa[crops_usa['Year'] == 2018]['Production']
production_2018_p
# Out:
# 37      7920000
# 38      7898000
# 39      5225000
# 40     11985000
# 41     70504000
# 42      3195000
# 43       360000
# 44      3780000
# 45    104410000
# 46     36960000
# 47     18460000
# 48       348000
# 49    277400000
# 50     19800000
# 51       650000
# 52     12600000
# 53     35720000
# 54     92930000
# 55      1470000
# 56     30680000
# 57    197630000
# 58     49490000
# 59       900000
# 60       930000
# 61      1575000
# 62      6555000
# 63     21090000
# 64    363483000
# 65     33750000
# 66     70000000
# 67     51590000
# 68      9425000
# 69      3510000
# 70     72294000
# 71     18525000
# 72     56000000
# 73      5356000
# 74      9300000
# 75    153210000
# 76       138000
# 77     14200000
# 78      3910000
# Name: Production, dtype: int64

# %%
# уникальные значения столбца Year
years_unique = crops_usa['Year'].unique()
# количество уникальных значений столбца Year
years_unique_count = crops_usa['Year'].nunique()
print(years_unique)
print(years_unique_count)
# Out:
# [2019 2018 2017 2016 2015 2014 2013 2012 2011 2010 2009 2008 2007 2006
#  2005 2004 2003 2002 2001 2000 1999 1998 1997 1996 1995 1994 1993 1992
#  1991 1990 1989 1988 1987 1986 1985 1984 1983 1982 1981 1980]
# 40

# %%
# уникальные значения столбца State
states_unique = crops_usa['State'].unique()
# количество уникальных значений столбца State
states_unique_count = crops_usa['State'].nunique()
print(states_unique)
print(states_unique_count)
# Out:
# ['ALABAMA' 'ARIZONA' 'ARKANSAS' 'CALIFORNIA' 'COLORADO' 'DELAWARE'
#  'GEORGIA' 'IDAHO' 'ILLINOIS' 'INDIANA' 'KANSAS' 'KENTUCKY' 'MARYLAND'
#  'MICHIGAN' 'MINNESOTA' 'MISSISSIPPI' 'MISSOURI' 'MONTANA' 'NEBRASKA'
#  'NEW JERSEY' 'NEW MEXICO' 'NEW YORK' 'NORTH CAROLINA' 'NORTH DAKOTA'
#  'OHIO' 'OKLAHOMA' 'OREGON' 'PENNSYLVANIA' 'SOUTH CAROLINA' 'SOUTH DAKOTA'
#  'TENNESSEE' 'TEXAS' 'UTAH' 'VIRGINIA' 'WASHINGTON' 'WISCONSIN' 'WYOMING'
#  'FLORIDA' 'IOWA' 'LOUISIANA' 'NEVADA' 'WEST VIRGINIA']
# 42

# %%
# значения Acres за 2019 год
acres_2019 = crops_usa[crops_usa['Year'] == 2019]['Acres']

# значения State за 2019 год
states_2019 = crops_usa[crops_usa['Year'] == 2019]['State']

# %%
print(acres_2019)
# Out:
# 0      130000
# 1       34000
# 2      110000
# 3      420000
# 4     2150000
# 5       60000
# 6      150000
# 7     1195000
# 8      650000
# 9      330000
# 10    6900000
# 11     460000
# 12     345000
# 13     540000
# 14    1450000
# 15      45000
# 16     550000
# 17    5450000
# 18    1070000
# 19      19000
# 20     360000
# 21      90000
# 22     290000
# 23    7505000
# 24     500000
# 25    4200000
# 26     740000
# 27     180000
# 28      70000
# 29    1500000
# 30     280000
# 31    4500000
# 32     125000
# 33     180000
# 34    2260000
# 35     195000
# 36     125000
# Name: Acres, dtype: int64

# %%
# print(states_2019)

# %%
sns.barplot(
    x=acres_2019,
    y=states_2019
)

plt.show()

# %% [markdown]
# ### Площадь посевов по штатам сильно различается. Судя по графику, за 90% посевов отвечают всего 10% штатов. Разумеется, это примерная оценка.

# %%
# значения столбца Production за 2019 год
production_2019 = crops_usa[crops_usa['Year'] == 2019]['Production']
states_2019 = crops_usa[crops_usa['Year'] == 2019]['State']

# %%
# постройте столбчатую диаграмму
sns.barplot(x=production_2019, y=states_2019)

plt.show()

# %% [markdown]
# ### Логично — где больше посевных площадей, там и больше урожая. Однако есть тонкости. Например, в TEXAS (штат Техас) в 2019 году собрали примерно столько же урожая, сколько в SOUTH DAKOTA (штат Южная Дакота). При этом в SOUTH DAKOTA в три раза меньше посевных площадей.

# %%
# 1) группируем данные по году (Year) с помощью groupby('Year')
# 2) достаём из сгруппированной таблицы только столбец с площадью посевов
# 3) суммируем значения в каждой группе с помощью sum()
acres_usa = crops_usa.groupby('Year')['Acres'].sum()
print(acres_usa)
# Out:
# Year
# 1980    80788000
# 1981    88251000
# 1982    86232000
# 1983    76419000
# 1984    79213000
# 1985    75535000
# 1986    71998000
# 1987    65829000
# 1988    65529000
# 1989    76615000
# 1990    77041000
# 1991    69881000
# 1992    72219000
# 1993    72168000
# 1994    70349000
# 1995    69031000
# 1996    75105000
# 1997    70412000
# 1998    65821000
# 1999    62664000
# 2000    62549000
# 2001    59432000
# 2002    60318000
# 2003    62141000
# 2004    59644000
# 2005    57214000
# 2006    57334000
# 2007    60460000
# 2008    63617000
# 2009    59017000
# 2010    52620000
# 2011    54277000
# 2012    55294000
# 2013    56236000
# 2014    56841000
# 2015    54999000
# 2016    50116000
# 2017    46052000
# 2018    47815000
# 2019    45158000
# Name: Acres, dtype: int64

# %%
acres_usa = crops_usa.groupby('Year')['Acres'].sum()
acres_usa
# Out:
# Year
# 1980    80788000
# 1981    88251000
# 1982    86232000
# 1983    76419000
# 1984    79213000
# 1985    75535000
# 1986    71998000
# 1987    65829000
# 1988    65529000
# 1989    76615000
# 1990    77041000
# 1991    69881000
# 1992    72219000
# 1993    72168000
# 1994    70349000
# 1995    69031000
# 1996    75105000
# 1997    70412000
# 1998    65821000
# 1999    62664000
# 2000    62549000
# 2001    59432000
# 2002    60318000
# 2003    62141000
# 2004    59644000
# 2005    57214000
# 2006    57334000
# 2007    60460000
# 2008    63617000
# 2009    59017000
# 2010    52620000
# 2011    54277000
# 2012    55294000
# 2013    56236000
# 2014    56841000
# 2015    54999000
# 2016    50116000
# 2017    46052000
# 2018    47815000
# 2019    45158000
# Name: Acres, dtype: int64

# %%
production_usa = crops_usa.groupby('Year')['Production'].sum()

# делим значения столбца production_usa на значения столбца acres_usa
yield_usa = production_usa / acres_usa
print(yield_usa)
# Out:
# Year
# 1980    29.471382
# 1981    31.561761
# 1982    32.064280
# 1983    31.665214
# 1984    32.756959
# 1985    32.092606
# 1986    29.036501
# 1987    32.017576
# 1988    27.654947
# 1989    26.582497
# 1990    35.432796
# 1991    28.335871
# 1992    34.157189
# 1993    33.206407
# 1994    32.992381
# 1995    31.619244
# 1996    30.322722
# 1997    35.242089
# 1998    38.700734
# 1999    36.632835
# 2000    35.622632
# 2001    32.767751
# 2002    26.623529
# 2003    37.727346
# 2004    36.161056
# 2005    36.762418
# 2006    31.541773
# 2007    33.924711
# 2008    39.484666
# 2009    37.428504
# 2010    41.106480
# 2011    36.721097
# 2012    40.733298
# 2013    37.964631
# 2014    35.648739
# 2015    37.490482
# 2016    46.066386
# 2017    37.803136
# 2018    39.426038
# 2019    42.520461
# dtype: float64

# %%
# достаём индексы (порядковые номера) столбца acres_usa, это числа от 1980 до 2019
years_unique = acres_usa.index.values
years_unique
# Out:
# array([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017, 2018, 2019], dtype=int64)

# %%
# постройте столбчатую диаграмму урожайности по годам
sns.barplot(x=years_unique, y=yield_usa)
plt.show()
