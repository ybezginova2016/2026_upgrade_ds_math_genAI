# %% [markdown]
# ## Web Scraping

# %%
import requests
from bs4 import BeautifulSoup

# %%
# specify the URL of the webpage you want to scrape
url = 'http://en.wikipedia.org/wiki/IBM'

# %%
# send an HTTP GET request to the webpage
response = requests.get(url)
response
# Out:
# <Response [403]>

# %%
# store the HTML content in a variable
html_content = response.text
html_content
# Out:
# 'Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.\n'

# %%
soup = BeautifulSoup(html_content, 'html.parser')
soup
# Out:
# C:\Users\HOME\AppData\Local\Temp\ipykernel_24920\1569724455.py:1: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, 'html.parser')
# Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.

# %%
# display a snippet of the HTML request
print(html_content[:300])
# Out:
# Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.

# %%
# притвориться браузером

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

print(response)
# Out:
# <Response [200]>

# %%
html = response.text
print(html[:500])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-menu-disabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 skin-theme-clientp

# %%
# find all <a> tags (anchor tags) in the HTML
links = soup.find_all('a')
links
# Out:
# []

# %%
# 4) request
response = requests.get(url, headers=headers)

# 5) get HTML
html = response.text

# 6) parse HTML
soup = BeautifulSoup(html, 'html.parser')

# 7) find links
links = soup.find_all('a')

print(len(links))  # должно быть много

# 8) print text
for l in links[:10]:
    print(l.text)
# Out:
# 2384
# Jump to content
# Main page
# Contents
# Current events
# Random article
# About Wikipedia
# Contact us
# Help
# Learn to edit
# Community portal
