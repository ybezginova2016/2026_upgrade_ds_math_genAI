# %% [markdown]
# ## Web Scraping

# %%
import requests
from bs4 import BeautifulSoup

# %%
# specify the URL of the webpage you want to scrape
url = 'http://en.wikipedia.org/wiki/IBM'

# %%
# send an HTTP GET request to the webpage
response = requests.get(url)
response
# Out:
# <Response [403]>

# %%
# store the HTML content in a variable
html_content = response.text
html_content
# Out:
# 'Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.\n'

# %%
soup = BeautifulSoup(html_content, 'html.parser')
soup
# Out:
# C:\Users\HOME\AppData\Local\Temp\ipykernel_24920\1569724455.py:1: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html_content, 'html.parser')
# Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.

# %%
# display a snippet of the HTML request
print(html_content[:300])
# Out:
# Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.

# %%
# притвориться браузером

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

print(response)
# Out:
# <Response [200]>

# %%
html = response.text
print(html[:500])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-menu-disabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 skin-theme-clientp

# %%
# find all <a> tags (anchor tags) in the HTML
links = soup.find_all('a')
links
# Out:
# []

# %%
# 4) request
response = requests.get(url, headers=headers)

# 5) get HTML
html = response.text

# 6) parse HTML
soup = BeautifulSoup(html, 'html.parser')

# 7) find links
links = soup.find_all('a')

print(len(links))  # должно быть много

# 8) print text
for l in links[:10]:
    print(l.text)
# Out:
# 2384
# Jump to content
# Main page
# Contents
# Current events
# Random article
# About Wikipedia
# Contact us
# Help
# Learn to edit
# Community portal

# %% [markdown]
# ### More Practice

# %%
from bs4 import BeautifulSoup
import requests

# %%
# %%html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Page Title</title>
# </head>
# <body>
# <h3><b id='boldest'>Lebron James</b></h3>
# <p> Salary: $ 92,000,000 </p>
# <h3> Stephen Curry</h3>
# <p> Salary: $85,000, 000 </p>
# <h3> Kevin Durant </h3>
# <p> Salary: $73,200, 000</p>
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Page Title</title>
# </head>
# <body>
# <h3><b id='boldest'>Lebron James</b></h3>
# <p> Salary: $ 92,000,000 </p>
# <h3> Stephen Curry</h3>
# <p> Salary: $85,000, 000 </p>
# <h3> Kevin Durant </h3>
# <p> Salary: $73,200, 000</p>
# </body>
# </html>

# %%
html="<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body></html>"

# %%
html
# Out:
# "<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body></html>"

# %%
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# <html><head><title>Page Title</title></head><body><h3><b id="boldest">Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body></html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Page Title
#   </title>
#  </head>
#  <body>
#   <h3>
#    <b id="boldest">
#     Lebron James
#    </b>
#   </h3>
#   <p>
#    Salary: $ 92,000,000
#   </p>
#   <h3>
#    Stephen Curry
#   </h3>
#   <p>
#    Salary: $85,000, 000
#   </p>
#   <h3>
#    Kevin Durant
#   </h3>
#   <p>
#    Salary: $73,200, 000
#   </p>
#  </body>
# </html>

# %%
tag_object = soup.title
print(tag_object)
# Out:
# <title>Page Title</title>

# %%
print(type(tag_object))
# Out:
# <class 'bs4.element.Tag'>

# %%
tag_object = soup.h3
tag_object
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
tag_child = tag_object.b
tag_child
# Out:
# <b id="boldest">Lebron James</b>

# %% [markdown]
# ### Children, Parents, and Siblings

# %%
parent_tag = tag_child.parent
parent_tag
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
tag_object.parent
# Out:
# <body><h3><b id="boldest">Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body>

# %%
sibling_1 = tag_object.next_sibling
sibling_1
# Out:
# <p> Salary: $ 92,000,000 </p>

# %%
sibling_2 = sibling_1.next_sibling
sibling_2
# Out:
# <h3> Stephen Curry</h3>

# %%
sibling_3 = sibling_2.next_sibling
sibling_3
# Out:
# <p> Salary: $85,000, 000 </p>

# %% [markdown]
# ### HTML Attributes

# %%
tag_child['id'] # accessing an attribute
# Out:
# 'boldest'

# %%
tag_child.attrs
# Out:
# {'id': 'boldest'}

# %%
tag_child.get('id')
# Out:
# 'boldest'

# %% [markdown]
# ### Navigable String

# %%
tag_string = tag_child.string
tag_string
# Out:
# 'Lebron James'

# %%
type(tag_string)
# Out:
# bs4.element.NavigableString

# %%
unicode_string = str(tag_string)
unicode_string
# Out:
# 'Lebron James'

# %%
# %%html
# <table>
#   <tr>
#     <td id='flight' >Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#    </tr>
#   <tr>
#     <td>1</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# Out:
# <table>
#   <tr>
#     <td id='flight' >Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#    </tr>
#   <tr>
#     <td>1</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td>
#     <td>80 kg</td>
#   </tr>
# </table>

# %%
table="<table><tr><td id='flight'>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a></td><td>300 kg</td></tr><tr><td>2</td><td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td><td>80 kg</td></tr></table>"
table
# Out:
# "<table><tr><td id='flight'>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a></td><td>300 kg</td></tr><tr><td>2</td><td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td><td>80 kg</td></tr></table>"

# %%
table_bs = BeautifulSoup(table, 'html.parser')
table_bs
# Out:
# <table><tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr><tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr></table>

# %%
# find All method
# find_all(name, attrs, recursive, string, limit, **kwargs)

table_rows = table_bs.find_all('tr')
table_rows
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr>]

# %%
first_row = table_rows[0]
first_row
# Out:
# <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>

# %%
type(first_row)
# Out:
# bs4.element.Tag

# %%
first_row.td
# Out:
# <td id="flight">Flight No</td>

# %%
for i, row in enumerate(table_rows):
    print('row', i, 'is', row)
# Out:
# row 0 is <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>
# row 1 is <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr>
# row 2 is <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>
# row 3 is <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr>

# %%
for i, row in enumerate(table_rows):
    print('row', i)
    cells = row.find_all('td')
    for j, cell in enumerate(cells):
        print('column', j, 'cell', cell)
# Out:
# row 0
# column 0 cell <td id="flight">Flight No</td>
# column 1 cell <td>Launch site</td>
# column 2 cell <td>Payload mass</td>
# row 1
# column 0 cell <td>1</td>
# column 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td>
# column 2 cell <td>300 kg</td>
# row 2
# column 0 cell <td>2</td>
# column 1 cell <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>
# column 2 cell <td>94 kg</td>
# row 3
# column 0 cell <td>3</td>
# column 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td>
# column 2 cell <td>80 kg</td>

# %%
list_input = table_bs.findAll(name = ['tr', 'td'])
list_input
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr>,
#  <td>1</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td>,
#  <td>300 kg</td>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <td>2</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>,
#  <td>94 kg</td>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr>,
#  <td>3</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td>,
#  <td>80 kg</td>]

# %%
# Attributes

table_bs.find_all(id = 'flight')
# Out:
# [<td id="flight">Flight No</td>]

# %%
list_input=table_bs.find_all(href="https://en.wikipedia.org/wiki/Florida")
list_input
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a>]

# %%
table_bs.find_all(href=True)
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a>,
#  <a href="https://en.wikipedia.org/wiki/Texas">Texas</a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a>]

# %%
table_bs.find_all(href=False)
# Out:
# [<table><tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr><tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr></table>,
#  <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr>,
#  <td>1</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td>,
#  <a></a>,
#  <td>300 kg</td>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <td>2</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>,
#  <td>94 kg</td>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr>,
#  <td>3</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td>,
#  <a> </a>,
#  <td>80 kg</td>]

# %%
table_bs.find_all(lambda tag: tag.name == 'a' and not tag.has_attr('href'))
# Out:
# [<a></a>, <a> </a>]

# %%
table_bs.find_all(lambda tag: tag.name != 'a' and not tag.find('a'))
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <td>1</td>,
#  <td>300 kg</td>,
#  <td>2</td>,
#  <td>94 kg</td>,
#  <td>3</td>,
#  <td>80 kg</td>]

# %%
table_bs.find_all(string = 'Seattle')
# Out:
# []

# %%
table_bs.find_all(string = 'Florida')
# Out:
# ['Florida', 'Florida']

# %%
# %%html
# <h3>Rocket Launch </h3>
#
# <p>
# <table class='rocket'>
#   <tr>
#     <td>Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Florida</td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Texas</td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Florida </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# </p>
# <p>
#
# <h3>Pizza Party  </h3>
#
#
# <table class='pizza'>
#   <tr>
#     <td>Pizza Place</td>
#     <td>Orders</td>
#     <td>Slices </td>
#    </tr>
#   <tr>
#     <td>Domino's Pizza</td>
#     <td>10</td>
#     <td>100</td>
#   </tr>
#   <tr>
#     <td>Little Caesars</td>
#     <td>12</td>
#     <td >144 </td>
#   </tr>
#   <tr>
#     <td>Papa John's </td>
#     <td>15 </td>
#     <td>165</td>
#   </tr>
# Out:
# <h3>Rocket Launch </h3>
#
# <p>
# <table class='rocket'>
#   <tr>
#     <td>Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Florida</td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Texas</td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Florida </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# </p>
# <p>
#
# <h3>Pizza Party  </h3>
#
#
# <table class='pizza'>
#   <tr>
#     <td>Pizza Place</td>
#     <td>Orders</td>
#     <td>Slices </td>
#    </tr>
#   <tr>
#     <td>Domino's Pizza</td>
#     <td>10</td>
#     <td>100</td>
#   </tr>
#   <tr>
#     <td>Little Caesars</td>
#     <td>12</td>
#     <td >144 </td>
#   </tr>
#   <tr>
#     <td>Papa John's </td>
#     <td>15 </td>
#     <td>165</td>
#   </tr>

# %%
two_tables="<h3>Rocket Launch </h3><p><table class='rocket'><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table></p><p><h3>Pizza Party  </h3><table class='pizza'><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td >144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr>"

# %%
two_tables_bs= BeautifulSoup(two_tables, 'html.parser')
two_tables_bs
# Out:
# <h3>Rocket Launch </h3><p><table class="rocket"><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table></p><p><h3>Pizza Party  </h3><table class="pizza"><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td>144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr></table></p>

# %%
two_tables_bs.find("table")
# Out:
# <table class="rocket"><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table>

# %%
two_tables_bs.find("table",class_='pizza')
# Out:
# <table class="pizza"><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td>144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr></table>

# %%
two_tables_bs.find("table",class_='rocket')
# Out:
# <table class="rocket"><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table>

# %%
url = 'https://www.ibm.com'
url
# Out:
# 'https://www.ibm.com'

# %%
data = requests.get(url).text

# %%
soup = BeautifulSoup(data, 'html.parser')
soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="en" name="languageCode"/>
# <meta content="us" name="countryCode"/>
# <meta content="IBM" name="searchTitle"/>
# <meta content="Cross IBM SDRs" name="focusArea"/>
# <meta content="IBM" name="primaryTaxonomyEn"/>
# <meta content="home" name="siteSection"/>
# <meta content="IBM" name="primaryTopic"/>
# <meta name="productName"/>
# <meta name="pageType"/>
# <title>IBM</title>
# <meta content="eROxip4tByGTXXkYPHZou7oTgw2e0GMdApm2VHP9JNKXdpCWq8mPAxUAd36QHdh0uX5DLAELN8kcObodQWtduQ" name="content-page-ref"/>
# <script data-routing="program=131558,environment=1281329,tier=publish" defer="defer" src="https://rum.hlx.page/.rum/@adobe/helix-rum-js@%5E2/dist/micro.js" type="text/javascript"></script>
# <link href="/content/dam/adobe-cms/default-images/icon-16x16.png" rel="icon" sizes="16x16"/>
# <link href="/content/dam/adobe-cms/default-images/icon-32x32.png" rel="icon" sizes="32x32"/>
# <link href="/content/dam/adobe-cms/default-images/icon-150x150.png" rel="icon" sizes="150x150"/>
# <link href="/content/dam/adobe-cms/default-images/icon-192x192.png" rel="icon" sizes="192x192"/>
# <link href="/content/dam/adobe-cms/default-images/icon-512x512.png" rel="icon" sizes="512x512"/>
# <link href="/content/dam/adobe-cms/default-images/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/content/dam/adobe-cms/default-images/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/content/dam/adobe-cms/default-images/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/content/dam/adobe-cms/default-images/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/content/dam/adobe-cms/default-images/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <meta content="For more than a century, IBM has been a global technology innovator, leading advances in AI, automation and hybrid cloud solutions that help businesses grow." name="description"/>
# <meta content="full-width-layout" name="template"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="index, follow, max-image-preview:large" name="robots"/>
# <link href="https://www.ibm.com/us-en" rel="canonical"/>
# <link as="script" href="/etc.clientlibs/adobe-cms/clientlibs/clientlib-masthead-container.lc-df92461c43509f256ad4cd26b2c27f29-lc.min.js" rel="preload"/>
# <script defer="" src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-smartling-context.lc-d30c41c1c7a4511befbe3e285d76955a-lc.min.js"></script>
# <script type="text/javascript">
#           !function(e, a, n, t) {
#               var i = e.head;
#               if (i) {
#                   if (a) return;
#                   var o = e.createElement("style");
#                   o.id = "alloy-prehiding", o.innerText = n, i.appendChild(o),
#                       setTimeout(function() {
#                           o.parentNode && o.parentNode.removeChild(o)
#                       }, t)
#               }
#           }
#           (document, document.location.href.indexOf("adobe_authoring_enabled") !== -1, "body { opacity: 0 !important }", 900);
#       </script>
# <!--      <script type="text/javascript">
#           (function(c,l,a,r,i,t,y){
#               c[a]=c[a]||function(){(c[a].q=c[a].q||[]).push(arguments)};
#               t=l.createElement(r);t.async=1;t.src="https://www.clarity.ms/tag/"+i;
#               y=l.getElementsByTagName(r)[0];y.parentNode.insertBefore(t,y);
#           })(window, document, "clarity", "script", "s52kp7iw7g");
#       </script>-->
# <style id="prevent-layout-shift-style">
#     c4d-masthead-container:not(:defined) {
#         min-height: 114px; /* Reserve space before it loads */
#         display: block !important;
#         opacity: 0; /* Hide visually but keep space */
#         transition: opacity 0.3s ease-in-out;
#     }
#
#     c4d-masthead-container:defined {
#         transition: opacity 0.3s ease-in-out;
#         opacity: 1;
#     }
#
#     c4d-leadspace:not(:defined) {
#         display:none;
#     }
#
#     c4d-table-of-contents:not(:defined) {
#         display:none;
#     }
#
#     c4d-link-list:not(:defined) {
#         display:none;
#     }
# </style>
# <script async="async" src="https://assets.adobedtm.com/0f2de1d5b89a/565c2aeb0d39/launch-560e54b3e83c.min.js" type="text/javascript"></script>
# <script async="async" type="text/javascript">
# 	var adobeDataLayer = window.adobeDataLayer || [];
# 	</script>
# <script type="text/javascript">
#         window.searchKey = {
#             templateName: 'full\u002Dwidth\u002Dlayout',
#             taxonomylist: 'taxonomy : Brands \/ IBM',
#             L0Tag: 'Topics,Brands,Industries,Geography,Compliance Entities,Product Categories,Events,Computer Languages,Content Format,Series,Content Type,CMaaS Focus Areas,brands,Deployment Types,Product Types,Search Index,Unified Taxonomy,Site Sections,Page Types',
#         }
#     </script>
# <link href="https://www.ibm.com/sa-ar" hreflang="ar-sa" rel="alternate">
# <link href="https://www.ibm.com/de-de" hreflang="de-de" rel="alternate"/>
# <link href="https://www.ibm.com/us-en" hreflang="en-us" rel="alternate"/>
# <link href="https://www.ibm.com/ca-en" hreflang="en-ca" rel="alternate"/>
# <link href="https://www.ibm.com/kr-ko" hreflang="ko-kr" rel="alternate"/>
# <link href="https://www.ibm.com/br-pt" hreflang="pt-br" rel="alternate"/>
# <link href="https://www.ibm.com/qa-ar" hreflang="ar-qa" rel="alternate"/>
# <link href="https://www.ibm.com/in-en" hreflang="en-in" rel="alternate"/>
# <link href="https://www.ibm.com/es-es" hreflang="es-es" rel="alternate"/>
# <link href="https://www.ibm.com/ae-ar" hreflang="ar-ae" rel="alternate"/>
# <link href="https://www.ibm.com/cn-zh" hreflang="zh-cn" rel="alternate"/>
# <link href="https://www.ibm.com/mx-es" hreflang="es-mx" rel="alternate"/>
# <link href="https://www.ibm.com/ca-fr" hreflang="fr-ca" rel="alternate"/>
# <link href="https://www.ibm.com/it-it" hreflang="it-it" rel="alternate"/>
# <link href="https://www.ibm.com/" hreflang="x-default" rel="alternate"/>
# <link href="https://www.ibm.com/id-id" hreflang="id-id" rel="alternate"/>
# <link href="https://www.ibm.com/au-en" hreflang="en-au" rel="alternate"/>
# <link href="https://www.ibm.com/uk-en" hreflang="en-uk" rel="alternate"/>
# <link href="https://www.ibm.com/fr-fr" hreflang="fr-fr" rel="alternate"/>
# <link href="https://www.ibm.com/jp-ja" hreflang="ja-jp" rel="alternate"/>
# <script type="text/javascript">
#         var languageCode = document.getElementsByName('languageCode')[0].content;
#         var countryCode = document.getElementsByName('countryCode')[0].content;
#         var focusArea = document.getElementsByName('focusArea')[0].content;
#         var primaryTopic = document.getElementsByName('primaryTopic')[0].content;
#         var productName = document.getElementsByName('productName')[0].content;
#         var pageType = document.getElementsByName('pageType')[0].content;
#
#         /* Define digital data object based on _appInfo object */
#           window._ibmAnalytics = {
#               settings: {
#                  name: "AEM Sites",
#                  tealiumProfileName: "adobe-launch"
#               },
#            };
#         window.digitalData = {
#             page: {
#                 category: {
#                     primaryCategory: '',
#                 },
#                 taxonomy: {
#                     primaryTopic: primaryTopic,
#                     productName: productName,
#                     pageType: pageType
#                 },
#                 pageInfo: {
#                     language: languageCode + '-' + countryCode,
#                     ibm: {
#                         siteID: 'MarketingAEM',
#                         country: countryCode,
#                         messaging: {
#                             routing: {
#                                 focusArea: focusArea,
#                                 languageCode: languageCode,
#                                 regionCode: countryCode
#                             },
#                             translation: {
#                                 languageCode: languageCode,
#                                 regionCode: countryCode
#                             }
#                         },
#                         sections: 0,
#                         patterns: 0,
#                     },
#                     carbon: {
#                         '@carbon/web-components': '',
#                         '@carbon/ibmdotcom-web-components': '',
#                         'carbon-for-aem': '',
#                     },
#                 },
#             },
#         };
#     </script>
# <script type="application/ld+json">
#             {
#                 "@context": "https://schema.org",
#                 "@type": "Corporation",
#                 "name": "IBM",
#                 "url": "[https://www.ibm.com/]",
#                 "logo": "[https://www.ibm.com/favicon.ico]",
#                 "sameAs": [
#                     "[https://www.linkedin.com/company/ibm]",
#                     "[https://x.com/IBM]",
#                     "[https://www.youtube.com/ibm]"
#                 ],
#                 "subOrganization": [{"@type": "Organization","name": "IBM Saudi Arabia","url": "[https://www.ibm.com/sa-ar/]"},{"@type": "Organization","name": "IBM Indonesia","url": "[https://www.ibm.com/id-id/]"},{"@type": "Organization","name": "IBM Mexico","url": "[https://www.ibm.com/mx-es/]"},{"@type": "Organization","name": "IBM China","url": "[https://www.ibm.com/cn-zh/]"},{"@type": "Organization","name": "IBM Qatar","url": "[https://www.ibm.com/qa-ar/]"},{"@type": "Organization","name": "IBM Germany","url": "[https://www.ibm.com/de-de/]"},{"@type": "Organization","name": "IBM United States","url": "[https://www.ibm.com/us-en/]"},{"@type": "Organization","name": "IBM Spain","url": "[https://www.ibm.com/es-es/]"},{"@type": "Organization","name": "IBM Italy","url": "[https://www.ibm.com/it-it/]"},{"@type": "Organization","name": "IBM Brazil","url": "[https://www.ibm.com/br-pt/]"},{"@type": "Organization","name": "IBM United Arab Emirates","url": "[https://www.ibm.com/ae-ar/]"},{"@type": "Organization","name": "IBM Japan","url": "[https://www.ibm.com/jp-ja/]"},{"@type": "Organization","name": "IBM France","url": "[https://www.ibm.com/fr-fr/]"},{"@type": "Organization","name": "IBM Korea","url": "[https://www.ibm.com/kr-ko/]"}]
#             }
#         </script>
# <!-- Instana script specific to Dev environment start -->
# <!--      <script>
#           (function(s,t,a,n){s[t]||(s[t]=a,n=s[a]=function(){n.q.push(arguments)},
#           n.q=[],n.v=2,n.l=1*new Date)})(window,"InstanaEumObject","ineum");
#
#           ineum('reportingUrl', 'https://eum-orange-saas.instana.io');
#           ineum('key', 'mFJnYtpBSiCKl9zenWHXtg');
#           ineum('trackSessions');
#       </script>
#       <script defer crossorigin="anonymous" src=https://eum.instana.io/1.7.2/eum.min.js
#               integrity="sha384-cgeSlevgebehPauohUhsnAeBrpjXzaj94mSv3L2EXjCQH0RRb9xSQ2ErGOWkthIJ"></script>-->
# <!-- Instana script specific to Dev environment end -->
# <meta content="https://www.ibm.com/us-en" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="IBM" property="og:title"/>
# <meta content="For more than a century, IBM has been a global technology innovator, leading advances in AI, automation and hybrid cloud solutions that help businesses grow." property="og:description"/>
# <meta content="https://www.ibm.com/content/dam/connectedassets-adobe-cms/worldwide-content/creative-assets/s-migr/ul/g/18/f9/ibm_logo_pos_blue60_rgb.png/_jcr_content/renditions/cq5dam.thumbnail.1280.1280.png" property="og:image"/>
# <script async="async" fetchpriority="high" src="https://1.www.s81c.com/common/stats/ibm-common.js" type="text/javascript"></script>
# <link as="script" href="https://hybrid-cloud-widgets-production.s3.us.cloud-object-storage.appdomain.cloud/loader.js" rel="preload"/>
# <script src="https://hybrid-cloud-widgets-production.s3.us.cloud-object-storage.appdomain.cloud/loader.js" type="application/javascript"></script>
# <link href="/etc.clientlibs/adobe-cms/clientlibs/clientlib-base.lc-30313e00669f877069f15dd099f23454-lc.min.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/adobe-cms/clientlibs/clientlib-idlStylesCarbon.lc-e907180d2950d3ed10121fb37ae044df-lc.min.css" rel="stylesheet" type="text/css"/>
# <link href="/etc.clientlibs/adobe-cms/clientlibs/clientlib-idlStyles.lc-525aefbc8540fb51d90a04dbdc448b24-lc.min.css" rel="stylesheet" type="text/css"/>
# <link href="https://1.www.s81c.com/common/carbon-for-ibm-dotcom/tag/v1/latest/plex.css" rel="stylesheet">
# <link href="https://1.www.s81c.com/common/carbon/plex/sans.css" rel="stylesheet">
# </link></link></link></head>
# <body class="content-page page basicpage publish" data-cmp-data-layer-enabled="" data-fullwidthtemplate="true" id="content-page-c8104b3589">
# <script>
#     window.CQ_Analytics = window.CQ_Analytics || {};
#     window.adobeDataLayer = window.adobeDataLayer || [];
#     adobeDataLayer.push({
#         page: JSON.parse("{\x22content\u002Dpage\u002Dc8104b3589\x22:{\x22@type\x22:\x22adobe\u002Dcms\/components\/structure\/content\u002Dpage\x22,\x22repo:modifyDate\x22:\x222026\u002D03\u002D16T16:29:36Z\x22,\x22dc:title\x22:\x22Homepage\x22,\x22xdm:template\x22:\x22\/conf\/adobe\u002Dcms\u002Deditable\/settings\/wcm\/templates\/full\u002Dwidth\u002Dlayout\x22,\x22xdm:language\x22:\x22en\x22,\x22xdm:tags\x22:[],\x22repo:path\x22:\x22\/content\/adobe\u002Dcms\/us\/en\/homepage.html\x22}}"),
#         event: 'cmp:show',
#         eventInfo: {
#             path: 'page.content\u002Dpage\u002Dc8104b3589'
#         }
#     });
# </script>
# <div class="page-modal-wrapper">
# </div>
# <c4d-video-cta-container>
# <div class="root container responsivegrid">
# <div class="cmp-container" id="container-9225520bd9">
# <div class="masthead">
# <c4d-masthead-container auth-method="profile-api" current-region-text="Your current region is" data-endpoint="#" different-region-text="Select a different region" has-cart="" has-contact="true" has-global="true" has-profile="" has-search="" no-other-region-text="This page is not available in any other regions">
# </c4d-masthead-container>
# <script defer="" src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-masthead-container.lc-df92461c43509f256ad4cd26b2c27f29-lc.min.js"></script>
# <script src="/etc.clientlibs/clientlibs/granite/jquery.lc-7842899024219bcbdb5e72c946870b79-lc.min.js"></script>
# <script src="/etc.clientlibs/adobe-cms/components/structure/navigation/masthead/clientlibs/site.lc-711ad564e3a268c6369631bf501f356b-lc.min.js"></script>
# <script src="/etc.clientlibs/adobe-cms/components/structure/navigation/masthead/clientlibs/country-restoration.lc-849dd35b12585fe0bf0fee55c31b147c-lc.min.js"></script>
# <script>
#     let l0Json = "{\x22profileMenu\x22:{\x22signedout\x22:[{\x22title\x22:\x22My IBM\x22,\x22url\x22:\x22https:\/\/myibm.ibm.com\/?lnk=mmi\x22},{\x22title\x22:\x22Log in\x22,\x22url\x22:\x22https:\/\/login.ibm.com\/oidc\/endpoint\/default\/authorize?redirect_uri=https%3A%2F%2Fmyibm.ibm.com%2FOIDCHandler.html\x26response_type=token\x26client_id=v18LoginProdCI\x26scope=openid\x26state=https%3A%2F%2Fwww.ibm.com\x26nonce=8675309\x22}],\x22signedin\x22:[{\x22title\x22:\x22My IBM\x22,\x22url\x22:\x22https:\/\/myibm.ibm.com\/?lnk=mmi\x22},{\x22title\x22:\x22Profile\x22,\x22url\x22:\x22https:\/\/myibm.ibm.com\/profile\/?lnk=mmi\x22},{\x22title\x22:\x22Billing\x22,\x22url\x22:\x22https:\/\/myibm.ibm.com\/billing\/?lnk=mmi\x22},{\x22title\x22:\x22Log out\x22,\x22url\x22:\x22https:\/\/myibm.ibm.com\/pkmslogout?filename=accountRedir.html\x22}]},\x22mastheadNav\x22:{\x22links\x22:[{\x22title\x22:\x22Software\x22,\x22url\x22:\x22\x22,\x22submenu\x22:{\x22sections\x22:[{\x22heading\x22:{\x22title\x22:\x22Artificial intelligence\x22,\x22url\x22:\x22https:\/\/www.ibm.com\/categories\/artificial\u002Dintelligence\u002Dproducts\x22,\x22description\x22:\x22\x22},\x22groups\x22:[{\x22heading\x22:{\x22title\x22:\x22\x22,\x22description\x22:\x22\x22},\x22links\x22:[{\x22title\x22:\x22Bob\x22,\x22url\x22:\x22https:\/\/www.ibm.com\/products\/bob\x22,\x22description\x22:\x22AI software development partner\x22},{\x22title\x22:\x22Maximo Application Suite\x22,\x22url\x22:\x22https:\/\/www.ibm.com\/products\/maximo\x22,\x22description\x22:\x22AI\u002Dpowered monitoring, predictive maintenance, and reliability planning, available as SaaS or on Red Hat OpenShift\x22},{\x22title\x22:\x22watsonx\x22,\x22url\x22:\x22https:\/\/www.ibm.com\/products\/watsonx?lnk=flatitem\x22,\x22description\x22:\x22AI and data platform\x22},{\x22title\x22:\x22watsonx Code Assistant\x22,\x22url\x22:\x22https:\/\/www.ibm.com\/products\/watsonx\u002Dcode\u002Dassistant?lnk=flatitem\x22,\x22description\x22:\x22Pre\u002Dtrained AI models for software development and modernization\x22},{\x22title\x22:\x22watsonx Orchestrate\x22,\x22url\x22:\x22https:\/\/www.ibm.com\/products\/watsonx\u002Dorchestrate\x22,\x22description\x22:\x22Generative AI and automation solution that empowers your business\x22},{\x22title\x22:\x22watsonx.data\x22,\x22url\x22:\x22https:\/\/www.ibm.com\/products\/watsonx\u002Ddata\x22,\x22description\x22:\x22Hybrid, open data lakehouse to power AI and analytics with all your data\x22},{\x22title\x22:\x22watsonx.data integration\x22,\x22url\x22:\x22https:\/\/www.ibm.com\/products\/watsonx\u002Ddata\u002Dintegration\x22,\x22description\x22:\x22Adaptive data integration tool designed to future proof your data integration\x22},{\x22title\x22:\x22watsonx.data intelligence\x22,\x22url\x22:\x22https:\/\/www.ibm.com\/products\/watsonx\u002Ddata\u002Dintelligence\x22,\x22description\x22:\x22Discover, curate and govern data assets across on prem and public, private or hybrid cloud\x22},{\x22title\x22:\x22watsonx.governance\x22,\x22url\x22:\x22https:\/\/www.ibm.com\/products\/watsonx\u002Dgovernance\x22,\x22description\x22:\x22Direct, manage and monitor your AI with a single platform\x22}]}]},{\x22heading\x22:{\x22title\x22:\x22Data \x26 analytics\x22,\x22url\x22:\x22https:\/\/www.ibm.com\/categories\/data\u002Danalytics\u002Dproducts\x22,\x22description\x22:\x22\x22},\x22groups\x22:[{\x22heading\x22:{\x22title\x22:\x22\x22,\x22description\x22:\x22\x22},\x22links\x22:[{\x22title\x22:\x22Cloud Databases for Elasticsearch\x22,\x22url\x22:\x22https:\/\/www.ibm.com\/products\/databases\u002Dfor\u002Delasticsearch\x22,\x22description\x22:\x22A powerful tool for rich data with a full\u002Dtext search engine and JSON document database indexing\x22},{\x22title\x22:\x22Cloud Pak for Data\x22,\x22url\x22:\x22https:\/\/www.ibm.com\/products\/cloud\u002Dpak\u002Dfor\u002Ddata?lnk=flatitem\x22,\x22description\x22:\x22Tools for data analysis, organization and management\x22},{\x22title\x22:\ ...
#     const searchPlaceholderText = "Search all of IBM";
#     const links = JSON.parse(l0Json).mastheadNav.links;
#     const unAuthenticated = JSON.parse(l0Json).profileMenu.signedout;
#     const authenticated = JSON.parse(l0Json).profileMenu.signedin;
#
#     const mastheadContainerEl = document.querySelector('c4d-masthead-container');
#
#     mastheadContainerEl.navLinks = links;
#     mastheadContainerEl.unauthenticatedProfileItems = unAuthenticated;
#     mastheadContainerEl.authenticatedProfileItems = authenticated;
#
#     const appendSearchPlaceholderText = () => {
#         const typeheadEl = mastheadContainerEl.querySelector('c4d-search-with-typeahead');
#         if (typeheadEl) {
#             typeheadEl.searchPlaceholder = searchPlaceholderText;
#             observer.disconnect();
#         }
#     }
#     let observer = new MutationObserver(appendSearchPlaceholderText);
#     observer.observe(mastheadContainerEl, {subtree: true, childList: true});
# </script>
# <script src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-new-design.lc-1afe370e8ff437dc87c32979f72abbae-lc.min.js"></script>
# <script type="text/javascript">
#     if (window.location.href.includes("/careers") || window.location.href.includes("/aialliance") ||  window.location.href.includes("www.aialliance.org")|| window.location.hostname.includes("businessofgovernment") ||  window.location.href.includes("/businessofgovernment"))
#       {
#          document.querySelector('c4d-masthead-container').setAttribute("has-search","false");
#          document.querySelector('c4d-masthead-container').setAttribute("has-profile","false");
#
#       }
#
#
#       if(window.location.hostname.includes("businessofgovernment") ||  window.location.href.includes("/businessofgovernment"))
#         {
#               // Start the function
#         updateTopNavHrefFromPlatform();
#         }
#
#      function updateTopNavHrefFromPlatform() {
#     // Step 1: get the masthead container
#     var mastheadContainer = document.querySelector('c4d-masthead-container');
#     if (!mastheadContainer) {
#         setTimeout(updateTopNavHrefFromPlatform, 5000); // retry if not yet loaded
#         return;
#     }
#
#     // Step 2: get the platform URL
#     var platformUrl = mastheadContainer.getAttribute('platformurl');
#     if (!platformUrl) {
#         console.log('No platformurl found');
#         return;
#     }
#
#     // Step 3: get the masthead shadow root
#     var masthead = document.querySelector('c4d-masthead');
#     if (!masthead || !masthead.shadowRoot) {
#         setTimeout(updateTopNavHrefFromPlatform, 5000);
#         return;
#     }
#
#     // Step 4: get the nav container inside shadow DOM
#     var navContainer = masthead.shadowRoot.querySelector('.cds--header__nav-container');
#     if (!navContainer) {
#         setTimeout(updateTopNavHrefFromPlatform, 5000);
#         return;
#     }
#
#     // Step 5: get the slot inside nav container
#     var slot = navContainer.querySelector('slot');
#     if (!slot) {
#         setTimeout(updateTopNavHrefFromPlatform, 5000);
#         return;
#     }
#
#     // Step 6: get all assigned nodes to the slot
#     var assignedNodes = slot.assignedNodes();
#     for (var i = 0; i < assignedNodes.length; i++) {
#         var node = assignedNodes[i];
#         if (node.tagName && node.tagName.toLowerCase() === 'c4d-top-nav-name') {
#             // Step 7: set href from platformurl
#             node.setAttribute('href', platformUrl);
#             console.log('Updated href to', platformUrl);
#         }
#     }
# }
#        document.addEventListener("DOMContentLoaded", function() {
#           const mastheadContainer = document.querySelector("c4d-masthead-container");
#
#         if (mastheadContainer && mastheadContainer.getAttribute("has-global") === "false") {
#             document.querySelector('.earth-language-icon').style.display = 'none';
#         }
#         else{
#             document.querySelector('.earth-language-icon').style.setProperty('display', 'block', 'important');
#         }
#
#     if (mastheadContainer && mastheadContainer.getAttribute("brand") === "businessofgovernment") {
#             const isMobile = window.matchMedia("(max-width: 671px)").matches;
#             if (isMobile) {
#                 const langIcon = document.querySelector('.earth-language-icon');
#                 if (langIcon) {
#                     langIcon.style.setProperty('display', 'none', 'important');
#                 }
#             } else {
#                 const search = document.querySelector('c4d-search-with-typeahead');
#                 const globalBar = document.querySelector('c4d-masthead-global-bar');
#                 if (search) search.style.display = 'none';
#                 if (globalBar) globalBar.style.display = 'none';
#             }
#         }
#
#
#       });
# </script>
# </div>
# <div class="container responsivegrid">
# <div class="cmp-container" id="container-35bfd5ef7a">
# </div>
# </div>
# <div class="leadspace-container container responsivegrid" id="mbox-leadspace">
# <div class="cmp-container" id="leadspace-container-1e918979ca">
# <div class="leadspace-expanded leadspace">
# <section class="cds--grid theme-white leadspace-expanded__container leadspace-expanded__container--tall leadspace-expanded__container--aside">
# <div class="cds--row leadspace-expanded__row">
# <div class="cds--col-lg-6 leadspace-expanded__column leadspace-expanded__column--content">
# <div>
# <div class="leadspace-expanded__navigation leadspace-expanded__navigation--tags">
# </div>
# <div id="mbox-heading">
# <h1 class="leadspace-expanded__heading expressive-heading-05" id="leadspaceSimpleTitle">
# <span class="enhanced-title text-color-blue-60">Accelerate enterprise AI</span>
# </h1>
# </div>
# </div>
# <div>
# <span class="lead-in">
# <div id="mbox-subheading">
# <div class="cms-richtext" data-dynamic-inner-content="description" id="rich-text-96264db101">
# <p>Deliver open and trusted AI, powered by hybrid cloud. Let's create smarter business.</p>
# </div>
# </div>
# </span>
# <div id="mbox-leadspace_cta">
# <c4d-button-group class="leadspace-expanded__action leadspace-expanded__action--button-group">
# <!-- Determine if selector includes 'tagName=c4d-button-group-item' -->
# <!-- C4D Markup for publish mode -->
# <a href="https://www.ibm.com/software/data-management?lnk=hpls1us" target="_self">
# <c4d-button-group-item cta-type="local" data-aem-autoid="aem--leadspace_cta-0" data-video-modal-type="media-center" href="https://www.ibm.com/software/data-management?lnk=hpls1us" kind="primary" target="_self">
# <span>Lead with trusted data</span>
# </c4d-button-group-item>
# </a>
# <script defer="" src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-button.lc-59d2a696a28b988a97efcea4cc5600a1-lc.min.js"></script>
# <a href="https://www.ibm.com/solutions/hybrid-cloud?lnk=hpls2us" target="_self">
# <c4d-button-group-item cta-type="local" data-aem-autoid="aem--leadspace_cta-1" data-video-modal-type="media-center" href="https://www.ibm.com/solutions/hybrid-cloud?lnk=hpls2us" kind="tertiary" target="_self">
# <span>Unlock hybrid cloud advantage</span>
# </c4d-button-group-item>
# </a>
# <!-- Fallback for author/edit mode -->
# </c4d-button-group>
# </div>
# </div>
# </div>
# <div class="cds--col-lg-8 leadspace-expanded__column leadspace-expanded__column--media">
# <div class="leadspace-expanded__column-inner">
# <div id="mbox-leadspace_visual">
# <caem-video-player-container aspect-ratio="4x3" hide-caption="true" intersection-mode="" playing-mode="inline" video-id="1_9pq89u9w">
# </caem-video-player-container>
# <script defer="" src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-caem-video-player.lc-a78a05617af4f81111cdc202d3dc9cd5-lc.min.js"></script>
# <div data-last-modified="Mon Mar 16 16:29:36 UTC 2026" data-last-published="Mon Mar 16 16:29:36 UTC 2026" data-template="/conf/adobe-cms-editable/settings/wcm/templates/full-width-layout" data-title="Homepage" id="caem-analytics-data">
# </div>
# </div>
# </div>
# </div>
# <div class="cds--col-lg-2 leadspace-expanded__column leadspace-expanded__column--aside">
# <div class="leadspace-expanded__column-inner newsfeed" id="mbox-leadspace-side">
# </div>
# </div>
# </div>
# </section>
# </div>
# </div>
# </div>
# <div class="table-of-contents container responsivegrid">
# <c4d-table-of-contents class="cmp-table-of-contents" data-autoid="c4d--tableofcontents" data-cmp-is="table-of-contents" stickyoffset="48" toc-hide="hidden" toc-layout="horizontal">
# <div class="cmp-table-of-contents" id="table-of-contents-b422012d4b">
# <div class="tile-group-container container responsivegrid">
# <div class="cds--col">
# <h5 class="expressive-heading-02">Recommended for you</h5>
# <div class="ibmcom-tile-group">
# <div class="ibmcom-tile" cta-type="local" data-video-modal-type="media-center" href="https://www.ibm.com/quantum/blog/international-year-of-quantum?lnk=hprc1us" label="Insight" target="_self">
# <div class="ibmcom-tile__outer">
# <div class="ibmcom-tile__wrapper">
# <div class="ibmcom-tile__image">
# <div><div class="image-dm image">
# <div class="cmp-image overlaywatermark" data-asset-id="6660f874-32ef-415b-a337-29bcc2b60359" data-cmp-aspectratio="1x1" data-cmp-data-layer='{"image-dm-bb08748f64":{"@type":"adobe-cms/components/content/atoms/image-dm","repo:modifyDate":"2026-03-16T09:11:15Z","dc:title":"Compute_ISO_still_master_1x1","image":{"repo:id":"6660f874-32ef-415b-a337-29bcc2b60359","repo:modifyDate":"2025-05-10T04:08:05Z","@type":"image/png","repo:path":"/content/dam/worldwide-content/gbs/cf/ul/g/f7/07/compute_iso_still_master_1x1b.png","xdm:tags":["properties:orientation/square"],"xdm:smartTags":{"diagram":0.813,"editorial photography":0.782,"graphic design":0.779,"network":0.768}}}}' data-cmp-dmimage="" data-cmp-filereference="/content/dam/worldwide-content/gbs/cf/ul/g/f7/07/compute_iso_still_master_1x1b.png" data-cmp-hook-image="imageV3IBM" data-cmp-is="image" data-cmp-src="https://assets.ibm.com/is/image/ibm/compute_iso_still_master_1x1b?ts=1773652275315&amp;dpr=off" data-cmp-widths="320,384,512,640,768,960,1024,1152,1280,1536,1584" id="image-dm-bb08748f64">
# <script type="application/json">
# 			{
# 				"widths": [320,384,512,640,768,960,1024,1152,1280,1536,1584],
# 				"maximagesize": "5000",
# 				"aspectratio": "1x1",
# 				"urls": {
# 					"dynamicmedia": "https://assets.ibm.com/is/image/ibm/compute_iso_still_master_1x1b?fmt=png-alpha",
# 					"adaptiveservlet": "/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2026675993_430496588/image.coreimg.png/1773652275315/compute-iso-still-master-1x1b.png",
# 					"assetdelivery": "/adobe/dynamicmedia/deliver/dm-aid--6660f874-32ef-415b-a337-29bcc2b60359/compute-iso-still-master-1x1b.png?preferwebp=true"
# 				},
# 				"usecustomcrop": "true",
# 				"customcrops": {
# 					"1x1": "https://assets.ibm.com/is/image/ibm/compute_iso_still_master_1x1b?cropN=0.11360338929329153,0.14702283508144245,0.8320282739811501,0.8320282739811501&wid=1584&hei=1584&fit=crop,1&fmt=png-alpha",
# 					"2x1": "",
# 					"3x2": "",
# 					"4x3": "",
# 					"5x2": "",
# 					"16x9": ""
# 				}
# 			}
# 		</script>
# <img alt="Abstract representation of computing system" class="cmp-image__image" height="2501" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/compute_iso_still_master_1x1b?ts=1773652275315&amp;dpr=off" srcset="..." width="2501"/>
# </div>
# <script defer="" src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-lightbox-media-viewer.lc-f774e7db89ab4a0f4e6755272dbd2e8b-lc.min.js"></script>
# </div>
# </div>
# </div>
# <div class="ibmcom-tile__content">
# <div class="ibmcom-tile__pictogram" hidden="hidden">
# </div>
# <span class="ibmcom-tile__label">Insight</span>
# <div class="ibmcom-tile__text">
# <div class="ibmcom-tile__text-inner mbox-tile-heading">Learn how global collaboration shaped the future of quantum computing</div>
# </div>
# <!-- pass tile-specific classes to the generic link template -->
# <div href="https://www.ibm.com/quantum/blog/international-year-of-quantum?lnk=hprc1us" style="display: contents;">
# <a aria-label="Look back at the International Year of Quantum" class="cds--link cds--link--lg cds--link-with-icon__icon-right cds--link-with-icon--inline-icon ibmcom-tile__action" cta-type="local" data-dynamic-properties='{"ctaUrl":"href"}' data-link-type="local" data-video-modal-type="media-center" href="https://www.ibm.com/quantum/blog/international-year-of-quantum?lnk=hprc1us" icon-placement="right" target="_self">
# <span class="cds--link-text" data-dynamic-inner-content="ctaLabel" data-link-text=""> Learn how global collaboration shaped the future of quantum computing</span>
# <!-- LTR - Left to Right version -->
# <svg aria-hidden="true" fill="currentColor" focusable="false" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg">
# <path d="M11.8 2.8L10.8 3.8 16.2 9.3 1 9.3 1 10.7 16.2 10.7 10.8 16.2 11.8 17.2 19 10z"></path>
# </svg>
# <!-- RTL - Right to Left version -->
# </a>
# </div>
#
# </div>
# </div>
# </div>
# </div>
# <div class="cmp-card-svg-source" hidden=""><svg id="accelerated-computing" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M19,29.36c-3.401,0-6.596-1.506-8.764-4.131l0.556-0.459c2.03,2.459,5.022,3.869,8.208,3.869 c5.867,0,10.64-4.772,10.64-10.64c0-5.867-4.772-10.64-10.64-10.64c-3.186,0-6.177,1.411-8.208,3.87l-0.555-0.459 c2.091-2.532,5.137-4.022,8.403-4.125V5.36H16c-0.199,0-0.36-0.161-0.36-0.36V3c0-0.199,0.161-0.36,0.36-0.36h6 c0.199,0,0.36,0.161,0.36,0.36v2c0,0.199-0.161,0.36-0.36,0.36h-2.64v1.286c6.098,0.191,11,5.211,11,11.354 C30.36,24.264,25.264,29.36,19,29.36z M16.36,4.64h5.28V3.36h-5.28V4.64z M14,23.36H4v-0.72h10V23.36z M12,18.36H2v-0.72h10V18.36z M19.179,18.312l-0.357-0.625l7-4l0.357,0.625L19.179,18.312z M14,13.36H4v-0.72h10V13.36z"></path></svg></div>
# <div class="ibmcom-tile" cta-type="external" data-video-modal-type="media-center" href="https://www.redhat.com/en/about/press-releases/red-hat-nvidia-pair-enterprise-open-source-rack-scale-ai-faster-production-ready-innovation?lnk=hprc2us" label="News" target="_blank">
# <div class="ibmcom-tile__outer">
# <div class="ibmcom-tile__wrapper">
# <div class="ibmcom-tile__image">
# <div><div class="image-dm image">
# <div class="cmp-image overlaywatermark" data-asset-id="46a54aaf-6265-470b-9c36-ff74ac59d007" data-cmp-aspectratio="1x1" data-cmp-data-layer='{"image-dm-e53be37ea3":{"@type":"adobe-cms/components/content/atoms/image-dm","repo:modifyDate":"2026-03-16T09:11:16Z","dc:title":"Red Hat/OpenShift - Top View","image":{"repo:id":"46a54aaf-6265-470b-9c36-ff74ac59d007","repo:modifyDate":"2026-03-13T20:29:28Z","@type":"image/png","repo:path":"/content/dam/worldwide-content/creative-assets/s-migr/ul/g/c5/83/redhat_top_still_master_1x1b.png","xdm:tags":["properties:orientation/square"],"xdm:smartTags":{"diagram":0.827}}}}' data-cmp-dmimage="" data-cmp-filereference="/content/dam/worldwide-content/creative-assets/s-migr/ul/g/c5/83/redhat_top_still_master_1x1b.png" data-cmp-hook-image="imageV3IBM" data-cmp-is="image" data-cmp-src="https://assets.ibm.com/is/image/ibm/redhat_top_still_master_1x1b?ts=1773652276943&amp;dpr=off" data-cmp-widths="320,384,512,640,768,960,1024,1152,1280,1536,1584" id="image-dm-e53be37ea3">
# <script type="application/json">
# 			{
# 				"widths": [320,384,512,640,768,960,1024,1152,1280,1536,1584],
# 				"maximagesize": "5000",
# 				"aspectratio": "1x1",
# 				"urls": {
# 					"dynamicmedia": "https://assets.ibm.com/is/image/ibm/redhat_top_still_master_1x1b?fmt=png-alpha",
# 					"adaptiveservlet": "/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_copy_15295_1739452896/image.coreimg.png/1773652276943/redhat-top-still-master-1x1b.png",
# 					"assetdelivery": "/adobe/dynamicmedia/deliver/dm-aid--46a54aaf-6265-470b-9c36-ff74ac59d007/redhat-top-still-master-1x1b.png?preferwebp=true"
# 				},
# 				"usecustomcrop": "true",
# 				"customcrops": {
# 					"1x1": "https://assets.ibm.com/is/image/ibm/redhat_top_still_master_1x1b?cropN=-2.7190349873507206E-4,0.23762915831056408,0.7626427659314956,0.7626427659314956&wid=1584&hei=1584&fit=crop,1&fmt=png-alpha",
# 					"2x1": "",
# 					"3x2": "",
# 					"4x3": "",
# 					"5x2": "",
# 					"16x9": ""
# 				}
# 			}
# 		</script>
# <img alt="An abstract representation of Red Hat integration" class="cmp-image__image" height="2345" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/redhat_top_still_master_1x1b?ts=1773652276943&amp;dpr=off" srcset="..." title="Abstract Data Visualization with Circular Interface Element" width="2345"/>
# </div>
# </div>
# </div>
# </div>
# <div class="ibmcom-tile__content">
# <div class="ibmcom-tile__pictogram" hidden="hidden">
# </div>
# <span class="ibmcom-tile__label">News</span>
# <div class="ibmcom-tile__text">
# <div class="ibmcom-tile__text-inner mbox-tile-heading">Accelerate AI from pilot to production at scale with Red Hat® and NVIDIA</div>
# </div>
# <!-- pass tile-specific classes to the generic link template -->
# <div href="https://www.redhat.com/en/about/press-releases/red-hat-nvidia-pair-enterprise-open-source-rack-scale-ai-faster-production-ready-innovation?lnk=hprc2us" style="display: contents;">
# <a aria-label="IBM's Red Hat® collaborates with NVIDIA" class="cds--link cds--link--lg cds--link-with-icon__icon-right cds--link-with-icon--inline-icon ibmcom-tile__action" cta-type="external" data-dynamic-properties='{"ctaUrl":"href"}' data-link-type="external" data-video-modal-type="media-center" href="https://www.redhat.com/en/about/press-releases/red-hat-nvidia-pair-enterprise-open-source-rack-scale-ai-faster-production-ready-innovation?lnk=hprc2us" icon-placement="right" target="_blank">
# <span class="cds--link-text" data-dynamic-inner-content="ctaLabel" data-link-text=""> Accelerate AI from pilot to production at scale with Red Hat® and NVIDIA</span>
# <!-- LTR - Left to Right version -->
# <!-- RTL - Right to Left version -->
# <svg aria-hidden="true" fill="currentColor" focusable="false" height="20" viewbox="0 0 32 32" width="20" xmlns="http://www.w3.org/2000/svg">
# <path d="M26,28H6a2.0027,2.0027,0,0,1-2-2V6A2.0027,2.0027,0,0,1,6,4H16V6H6V26H26V16h2V26A2.0027,2.0027,0,0,1,26,28Z"></path>
# <path d="M20 2L20 4 26.586 4 18 12.586 19.414 14 28 5.414 28 12 30 12 30 2 20 2z"></path>
# </svg>
# </a>
# </div>
#
# </div>
# </div>
# </div>
# </div>
# <div class="cmp-card-svg-source" hidden=""><svg id="accelerated-computing" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M19,29.36c-3.401,0-6.596-1.506-8.764-4.131l0.556-0.459c2.03,2.459,5.022,3.869,8.208,3.869 c5.867,0,10.64-4.772,10.64-10.64c0-5.867-4.772-10.64-10.64-10.64c-3.186,0-6.177,1.411-8.208,3.87l-0.555-0.459 c2.091-2.532,5.137-4.022,8.403-4.125V5.36H16c-0.199,0-0.36-0.161-0.36-0.36V3c0-0.199,0.161-0.36,0.36-0.36h6 c0.199,0,0.36,0.161,0.36,0.36v2c0,0.199-0.161,0.36-0.36,0.36h-2.64v1.286c6.098,0.191,11,5.211,11,11.354 C30.36,24.264,25.264,29.36,19,29.36z M16.36,4.64h5.28V3.36h-5.28V4.64z M14,23.36H4v-0.72h10V23.36z M12,18.36H2v-0.72h10V18.36z M19.179,18.312l-0.357-0.625l7-4l0.357,0.625L19.179,18.312z M14,13.36H4v-0.72h10V13.36z"></path></svg></div>
# <div class="ibmcom-tile" cta-type="local" data-video-modal-type="media-center" href="https://www.ibm.com/think/ai-agents?lnk=hprc3us" label="Guide" target="_self">
# <div class="ibmcom-tile__outer">
# <div class="ibmcom-tile__wrapper">
# <div class="ibmcom-tile__image">
# <div><div class="image-dm image">
# <div class="cmp-image overlaywatermark" data-asset-id="80bc16bb-149c-4507-82d7-c8fd6b0b10b9" data-cmp-aspectratio="1x1" data-cmp-data-layer='{"image-dm-6d1aafde92":{"@type":"adobe-cms/components/content/atoms/image-dm","repo:modifyDate":"2026-03-16T09:11:40Z","dc:title":"ai strategy plan iso","image":{"repo:id":"80bc16bb-149c-4507-82d7-c8fd6b0b10b9","repo:modifyDate":"2025-12-20T09:14:32Z","@type":"image/jpeg","repo:path":"/content/dam/worldwide-content/creative-assets/ibs/ul/cpi/9c/57/12_ai_strategy_plan_iso-1x1-b.jpg","xdm:tags":["properties:orientation/square"],"xdm:smartTags":{"duplicator":0.805,"turntable":0.789,"electronic equipment":0.769,"hard disk":0.807}}}}' data-cmp-dmimage="" data-cmp-filereference="/content/dam/worldwide-content/creative-assets/ibs/ul/cpi/9c/57/12_ai_strategy_plan_iso-1x1-b.jpg" data-cmp-hook-image="imageV3IBM" data-cmp-is="image" data-cmp-src="https://assets.ibm.com/is/image/ibm/12_ai_strategy_plan_iso-1x1-b?ts=1773652300920&amp;dpr=off" data-cmp-widths="320,384,512,640,768,960,1024,1152,1280,1536,1584" id="image-dm-6d1aafde92">
# <script type="application/json">
# 			{
# 				"widths": [320,384,512,640,768,960,1024,1152,1280,1536,1584],
# 				"maximagesize": "5000",
# 				"aspectratio": "1x1",
# 				"urls": {
# 					"dynamicmedia": "https://assets.ibm.com/is/image/ibm/12_ai_strategy_plan_iso-1x1-b",
# 					"adaptiveservlet": "/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_copy_copy_/image.coreimg.jpeg/1773652300920/12-ai-strategy-plan-iso-1x1-b.jpeg",
# 					"assetdelivery": "/adobe/dynamicmedia/deliver/dm-aid--80bc16bb-149c-4507-82d7-c8fd6b0b10b9/12-ai-strategy-plan-iso-1x1-b.jpg?preferwebp=true"
# 				},
# 				"usecustomcrop": "false",
# 				"customcrops": {
# 					"1x1": "",
# 					"2x1": "",
# 					"3x2": "",
# 					"4x3": "",
# 					"5x2": "",
# 					"16x9": ""
# 				}
# 			}
# 		</script>
# <img alt="An abstract representation of AI strategy" class="cmp-image__image" height="1920" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/12_ai_strategy_plan_iso-1x1-b?ts=1773652300920&amp;dpr=off" srcset="..." title="Futuristic device with circular interface" width="1920"/>
# </div>
# </div>
# </div>
# </div>
# <div class="ibmcom-tile__content">
# <div class="ibmcom-tile__pictogram" hidden="hidden">
# </div>
# <span class="ibmcom-tile__label">Guide</span>
# <div class="ibmcom-tile__text">
# <div class="ibmcom-tile__text-inner mbox-tile-heading">Explore a collection of AI agent-related content</div>
# </div>
# <!-- pass tile-specific classes to the generic link template -->
# <div href="https://www.ibm.com/think/ai-agents?lnk=hprc3us" style="display: contents;">
# <a aria-label="IBM's 2026 Guide to AI Agents" class="cds--link cds--link--lg cds--link-with-icon__icon-right cds--link-with-icon--inline-icon ibmcom-tile__action" cta-type="local" data-dynamic-properties='{"ctaUrl":"href"}' data-link-type="local" data-video-modal-type="media-center" href="https://www.ibm.com/think/ai-agents?lnk=hprc3us" icon-placement="right" target="_self">
# <span class="cds--link-text" data-dynamic-inner-content="ctaLabel" data-link-text=""> Explore a collection of AI agent-related content</span>
# <!-- LTR - Left to Right version -->
# <svg aria-hidden="true" fill="currentColor" focusable="false" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg">
# <path d="M11.8 2.8L10.8 3.8 16.2 9.3 1 9.3 1 10.7 16.2 10.7 10.8 16.2 11.8 17.2 19 10z"></path>
# </svg>
# <!-- RTL - Right to Left version -->
# </a>
# </div>
#
# </div>
# </div>
# </div>
# </div>
# <div class="cmp-card-svg-source" hidden=""><svg id="accelerated-computing" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M19,29.36c-3.401,0-6.596-1.506-8.764-4.131l0.556-0.459c2.03,2.459,5.022,3.869,8.208,3.869 c5.867,0,10.64-4.772,10.64-10.64c0-5.867-4.772-10.64-10.64-10.64c-3.186,0-6.177,1.411-8.208,3.87l-0.555-0.459 c2.091-2.532,5.137-4.022,8.403-4.125V5.36H16c-0.199,0-0.36-0.161-0.36-0.36V3c0-0.199,0.161-0.36,0.36-0.36h6 c0.199,0,0.36,0.161,0.36,0.36v2c0,0.199-0.161,0.36-0.36,0.36h-2.64v1.286c6.098,0.191,11,5.211,11,11.354 C30.36,24.264,25.264,29.36,19,29.36z M16.36,4.64h5.28V3.36h-5.28V4.64z M14,23.36H4v-0.72h10V23.36z M12,18.36H2v-0.72h10V18.36z M19.179,18.312l-0.357-0.625l7-4l0.357,0.625L19.179,18.312z M14,13.36H4v-0.72h10V13.36z"></path></svg></div>
# <div class="ibmcom-tile" cta-type="local" data-video-modal-type="media-center" href="https://www.ibm.com/new/product-blog/the-ai-factory-an-enterprise-transformation-engine?lnk=hprc4us" label="Case study" target="_self">
# <div class="ibmcom-tile__outer">
# <div class="ibmcom-tile__wrapper">
# <div class="ibmcom-tile__image">
# <div><div class="image-dm image">
# <div class="cmp-image overlaywatermark" data-asset-id="8c30c253-d763-4906-b7f9-d7d8b4d7d633" data-cmp-aspectratio="1x1" data-cmp-data-layer='{"image-dm-6621d11b35":{"@type":"adobe-cms/components/content/atoms/image-dm","repo:modifyDate":"2026-03-16T09:11:52Z","dc:title":"techmanage iso","image":{"repo:id":"8c30c253-d763-4906-b7f9-d7d8b4d7d633","repo:modifyDate":"2025-12-20T09:14:26Z","@type":"image/jpeg","repo:path":"/content/dam/worldwide-content/creative-assets/ibs/ul/cpi/0d/e7/15_techmanage_iso-1x1-b.jpg","xdm:tags":["properties:orientation/square"],"xdm:smartTags":{"product photography":0.773,"network":0.76}}}}' data-cmp-dmimage="" data-cmp-filereference="/content/dam/worldwide-content/creative-assets/ibs/ul/cpi/0d/e7/15_techmanage_iso-1x1-b.jpg" data-cmp-hook-image="imageV3IBM" data-cmp-is="image" data-cmp-src="https://assets.ibm.com/is/image/ibm/15_techmanage_iso-1x1-b?ts=1773652312786&amp;dpr=off" data-cmp-widths="320,384,512,640,768,960,1024,1152,1280,1536,1584" id="image-dm-6621d11b35">
# <script type="application/json">
# 			{
# 				"widths": [320,384,512,640,768,960,1024,1152,1280,1536,1584],
# 				"maximagesize": "5000",
# 				"aspectratio": "1x1",
# 				"urls": {
# 					"dynamicmedia": "https://assets.ibm.com/is/image/ibm/15_techmanage_iso-1x1-b",
# 					"adaptiveservlet": "/content/adobe-cms/us/en/homepage/jcr:content/root/table_of_contents/tile_group_container/container/tile_card_2026675993_446952913/image.coreimg.jpeg/1773652312786/15-techmanage-iso-1x1-b.jpeg",
# 					"assetdelivery": "/adobe/dynamicmedia/deliver/dm-aid--8c30c253-d763-4906-b7f9-d7d8b4d7d633/15-techmanage-iso-1x1-b.jpg?preferwebp=true"
# 				},
# 				"usecustomcrop": "true",
# 				"customcrops": {
# 					"1x1": "https://assets.ibm.com/is/image/ibm/15_techmanage_iso-1x1-b?cropN=0.08836324382450483,0.06661229149847288,0.7960848219434504,0.7960848219434504&wid=1584&hei=1584&fit=crop,1",
# 					"2x1": "",
# 					"3x2": "",
# 					"4x3": "",
# 					"5x2": "",
# 					"16x9": ""
# 				}
# 			}
# 		</script>
# <img alt="An abstract representation of tech management" class="cmp-image__image" height="1920" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/15_techmanage_iso-1x1-b?ts=1773652312786&amp;dpr=off" srcset="..." title="Futuristic data device with blue disc" width="1920"/>
# </div>
# </div>
# </div>
# </div>
# <div class="ibmcom-tile__content">
# <div class="ibmcom-tile__pictogram" hidden="hidden">
# </div>
# <span class="ibmcom-tile__label">Case study</span>
# <div class="ibmcom-tile__text">
# <div class="ibmcom-tile__text-inner mbox-tile-heading">Power enterprise transformation with Dell AI Factory and NVIDIA</div>
# <div class="cmp-tags">
# </div>
# </div>
# <!-- pass tile-specific classes to the generic link template -->
# <div href="https://www.ibm.com/new/product-blog/the-ai-factory-an-enterprise-transformation-engine?lnk=hprc4us" style="display: contents;">
# <a aria-label="IBM Consulting powers enterprise transformation with Dell AI Factory with NVIDIA as the engine" class="cds--link cds--link--lg cds--link-with-icon__icon-right cds--link-with-icon--inline-icon ibmcom-tile__action" cta-type="local" data-dynamic-properties='{"ctaUrl":"href"}' data-link-type="local" data-video-modal-type="media-center" href="https://www.ibm.com/new/product-blog/the-ai-factory-an-enterprise-transformation-engine?lnk=hprc4us" icon-placement="right" target="_self">
# <span class="cds--link-text" data-dynamic-inner-content="ctaLabel" data-link-text=""> Power enterprise transformation with Dell AI Factory and NVIDIA</span>
# <!-- LTR - Left to Right version -->
# <svg aria-hidden="true" fill="currentColor" focusable="false" height="20" viewbox="0 0 20 20" width="20" xmlns="http://www.w3.org/2000/svg">
# <path d="M11.8 2.8L10.8 3.8 16.2 9.3 1 9.3 1 10.7 16.2 10.7 10.8 16.2 11.8 17.2 19 10z"></path>
# </svg>
# <!-- RTL - Right to Left version -->
# </a>
# </div>
#
# </div>
# </div>
# </div>
# </div>
# <div class="cmp-card-svg-source" hidden=""><svg id="accelerated-computing" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path d="M19,29.36c-3.401,0-6.596-1.506-8.764-4.131l0.556-0.459c2.03,2.459,5.022,3.869,8.208,3.869 c5.867,0,10.64-4.772,10.64-10.64c0-5.867-4.772-10.64-10.64-10.64c-3.186,0-6.177,1.411-8.208,3.87l-0.555-0.459 c2.091-2.532,5.137-4.022,8.403-4.125V5.36H16c-0.199,0-0.36-0.161-0.36-0.36V3c0-0.199,0.161-0.36,0.36-0.36h6 c0.199,0,0.36,0.161,0.36,0.36v2c0,0.199-0.161,0.36-0.36,0.36h-2.64v1.286c6.098,0.191,11,5.211,11,11.354 C30.36,24.264,25.264,29.36,19,29.36z M16.36,4.64h5.28V3.36h-5.28V4.64z M14,23.36H4v-0.72h10V23.36z M12,18.36H2v-0.72h10V18.36z M19.179,18.312l-0.357-0.625l7-4l0.357,0.625L19.179,18.312z M14,13.36H4v-0.72h10V13.36z"></path></svg></div>
# </div>
# </div>
# <script defer="" src="/etc.clientlibs/adobe-cms/clientlibs/clientlib-image.lc-b71fd9c4975562f3350b5f3e3e4e5af6-lc.min.js"></script>
# <script defer="" src="/etc.clientlibs/adobe-cms/components/content/organisms/tile-group/tile-group-container/clientlibs.lc-7765080e6ee21326256a1572435cc07b-lc.min.js"></script>
# </div>
# <div class="logo-tabs-container"><div class="cmp-logo-tabs-container">
# <h2 class="cmp-logo-tabs-container__heading">
# <span class="enhanced-title">Smarter business. Real impact.</span>
# </h2>
# <div>
# ...
#                                     "web": {
#                                         "webPageDetails": {
#                                              "URL": document.URL,
#                                              "name": cleanUrl(window.location.host) + " | " + templateName + " | " + "Homepage" ,
#                                              "siteSection": firstSegment
#                                         },
#                                         "webReferrer": {
#                                             "URL": document.referrer
#                                         }
#                                     }
#                             });
#                     }
#
#                 function checkForVideo(container) {
#                     var iframe = container.querySelector('iframe');
#                     if (!iframe) return null;
#
#                     try {
#                             return iframe.contentDocument ? iframe.contentDocument.querySelector('video') : null;
#                         } catch (e) {
#                             console.error('Unable to access iframe content for ' + videoName + ':', e);
#                             return null;
#                         }
#                 }
#
#                 function trackVideoProgress(video) {
#                     if (video.hasTracking) return;
#                     video.hasTracking = true;
#
#                     var milestones = {
#                         reachedStart: false,
#                         reached25: false,
#                         reached50: false,
#                         reached75: false,
#                         completed: false
#                     };
#
#                     var handleFirstPlay = function () {
#                             if (!milestones.reachedStart) {
#                                 milestones.reachedStart = true;
#                                 pushVideoEvent("videoStart");
#                             }
#                     };
#
#                     video.addEventListener("playing", handleFirstPlay, {
#                         once: true
#                     });
#
#                     if (!video.paused) {
#                         handleFirstPlay();
#                     }
#
#                     video.addEventListener("timeupdate", function () {
#                         var percentageWatched = (video.currentTime / video.duration) * 100;
#
#                         if (percentageWatched >= 25 && !milestones.reached25) {
#                             milestones.reached25 = true;
#                             pushVideoEvent("video25");
#                         }
#
#                         if (percentageWatched >= 50 && !milestones.reached50) {
#                             milestones.reached50 = true;
#                             pushVideoEvent("video50");
#                         }
#
#                         if (percentageWatched >= 75 && !milestones.reached75) {
#                             milestones.reached75 = true;
#                             pushVideoEvent("video75");
#                         }
#
#                         if (percentageWatched >= 100 && !milestones.completed) {
#                             milestones.completed = true;
#                             video.removeEventListener("timeupdate", arguments.callee);
#                             pushVideoEvent("videoComplete");
#                         }
#                     });
#                 }
#
#                 function setupVideoTracking() {
#                     setTimeout(function () {
#                         var container = videoPlayer.querySelector('.kWidgetIframeContainer');
#                         if (!container) {
#                             console.log('No video container found inside ' + videoName);
#                             return;
#                         }
#
#                         var video = checkForVideo(container);
#                         if (video) {
#                             if (videoPlayer.hasAttribute('background-mode')) {
#                                     //console.log('Skipping tracking for background-mode video: ' + videoName);
#                                     return;
#                             }
#                             trackVideoProgress(video);
#                         } else {
#                             console.log('No video found inside ' + videoName);
#                         }
#                     }, 3000);
#                 }
#
#                 var container = videoPlayer.querySelector('.kWidgetIframeContainer');
#                 if (container && checkForVideo(container)) {
#                     setupVideoTracking();
#                 } else {
#                          videoPlayer.addEventListener('click', function () {
#                             if (!videoPlayer.videoTrackingStarted) {
#                                    videoPlayer.videoTrackingStarted = true;
#                                     setupVideoTracking();
#                             }
#                         }, { once: true });
#                 }
#
#               })(videoPlayers[i], i);
#             }
#         }
#         /*  */
#
#         function getVisitDepth() {
#             let pageVisitCount = sessionStorage.getItem('pageVisitCount');
#             pageVisitCount = pageVisitCount ? parseInt(pageVisitCount, 10) : 0;
#             pageVisitCount++;
#             sessionStorage.setItem('pageVisitCount', pageVisitCount);
#             return pageVisitCount;
#         }
#
#         function getAmPm() {
#             const date = new Date();
#             const hours = date.getHours();
#             return hours >= 12 ? "PM" : "AM";
#         }
#
#         function getCurrentDay() {
#             const date = new Date();
#             return new Intl.DateTimeFormat('en-US', { weekday: 'long' }).format(date);
#         }
#
#         function getDayOfMonth() {
#             const date = new Date();
#             return date.getDate();
#         }
#
#         function getDayOfWeekAsInteger() {
#             const date = new Date();
#             return date.getDay();
#         }
#
#         function getDayOfYear() {
#             const date = new Date();
#             const startOfYear = new Date(date.getFullYear(), 0, 1);
#             const diffInMillis = date - startOfYear;
#             const dayOfYear = Math.floor(diffInMillis / (1000 * 60 * 60 * 24)) + 1;
#             return dayOfYear;
#         }
#
#         function getCurrentHour() {
#             var currentHour = new Date().getHours();
#             var formattedHour = (currentHour === 0 ? 24 : currentHour);
#             return formattedHour + ":00";
#         }
#
#         function getCurrentHourInADay() {
#             const date = new Date();
#             let hours = date.getHours();
#             const period = hours >= 12 ? "PM" : "AM";
#             hours = hours % 12 || 12;
#             return hours +":00" +" " + period;
#         }
#
#         function getCurrentMinute() {
#             const date = new Date();
#             return date.getMinutes();
#         }
#
#         function getCurrentMonth() {
#             const date = new Date();
#             return date.getMonth() + 1;
#         }
#
#         function printCurrentMonthName() {
#             const months = ["January", "February", "March", "April", "May", "June",
#                     "July", "August", "September", "October", "November", "December"];
#             const date = new Date();
#             const monthName = months[date.getMonth()];
#             return monthName;
#         }
#
#         function getQuarter(date = new Date()) {
#             var year = date.getFullYear();
#             var quarters = [
#                             { start: "Jan", end: "Mar" },
#                             { start: "Apr", end: "Jun" },
#                             { start: "Jul", end: "Sep" },
#                             { start: "Oct", end: "Dec" }
#                            ];
#
#             var quarterIndex = Math.floor(date.getMonth() / 3);
#             var start = quarters[quarterIndex].start;
#             var end = quarters[quarterIndex].end;
#             return start + " " + year + " - " + end + " " + year;
#         }
#
#         function getCurrentQuarter() {
#             const date = new Date();
#             const month = date.getMonth();
#             const quarter = Math.floor(month / 3) + 1;
#             return quarter;
#         }
#
#         function getCurrentWeek() {
#             const date = new Date();
#             const startOfYear = new Date(date.getFullYear(), 0, 1);
#             const diff = date - startOfYear;
#             const oneWeekInMillis = 1000 * 60 * 60 * 24 * 7;
#             const weekNumber = Math.ceil(diff / oneWeekInMillis);
#             return weekNumber;
#         }
#
#         function getDayType() {
#             const date = new Date();
#             const dayOfWeek = date.getDay();
#              if (dayOfWeek === 0 || dayOfWeek === 6) {
#                 return "Weekend";
#              } else {
#                         return "Weekday";
#                     }
#         }
#
#         function getCurrentYear() {
#             const date = new Date();
#             return date.getFullYear();
#         }
#
#         function generateUtCodesObject() {
#             const utCodesMeta = document.querySelector('meta[name="ut-codes"]');
#             const utCodesIdMeta = document.querySelector('meta[name="ut-codes-id"]');
#             if (utCodesMeta && utCodesIdMeta) {
#                 const utCodesContent = utCodesMeta.getAttribute('content');
#                 const utCodesIdContent = utCodesIdMeta.getAttribute('content');
#                 const utCodesArray = utCodesContent.split(" > ");
#                 const utCodesIdArray = utCodesIdContent.split(" > ");
#                 let utCodes = {};
#                 utCodesArray.forEach((code, index) => {
#                     const firstTwoLetters = code.substring(0, 2);
#                     let prefix = '';
#                     switch (firstTwoLetters) {
#                         case '10':
#                         prefix = 'BusinessUnit';
#                         break;
#                         case '15':
#                         prefix = 'LineOfBusiness';
#                         break;
#                         case '17':
#                         prefix = 'Market';
#                         break;
#                         case '20':
#                         prefix = 'OfferingPortfolio';
#                         break;
#                         case '30':
#                         prefix = 'Offering';
#                         break;
#                         default:
#                         prefix = 'Unknown';
#                     }
#
#                     const codeKey = 'ut' + firstTwoLetters + prefix;
#                     const codeName = code + ':' + (utCodesIdArray[index] || "");
#                     utCodes[codeKey] = codeName;
#                 });
#
#                 return utCodes;
#             }
#
#             return {};
#         }
#
#         function isFirstPageVisited() {
#             const domainKey = 'firstPageVisited_' + window.location.hostname;
#             if (!localStorage.getItem(domainKey)) {
#                 localStorage.setItem(domainKey, 'true');
#                 return true;
#             }
#             return false;
#         }
#
#         function getQueryParamWithKey(paramName) {
#             const urlObj = new URL(window.location.href);
#             const value = urlObj.searchParams.get(paramName);
#             if (urlObj.searchParams.has(paramName)) {
#                 return paramName + '=' + value;
#             }
#             return '';
#         }
#
#         function getQueryParam(name) {
#             const queryString = window.location.search.substring(1);
#             if (name === '?') {
#                 return queryString;
#             }
#
#             const urlParams = new URLSearchParams(queryString);
#             return urlParams.get(name);
#         }
#
#         const utCodes = generateUtCodesObject();
#         const pmpDataScript = "{\x22platforms\x22:[]}";
#         let pmpItems = [];
#         if (pmpDataScript) {
#                try {
#                    pmpItems = JSON.parse(pmpDataScript);
#                } catch (e) {
#                       console.error("error: " + e);
#                }
#         }
#
#         var journeyStep = "";
#
#         var pageObj = {
#                     utCodes: utCodes,
#                     "pageQueryString":{
#                             "pageQueryString": getQueryParam('?') || "" ,
#                             "utm_content": getQueryParam('utm_content') || "",
#                             "utm_term": getQueryParam('utm_term') || "",
#                             "utm_medium": getQueryParam('utm_medium') || "",
#                             "utm_source": getQueryParam('utm_source') || "",
#                             "utm_campaign": getQueryParam('utm_campaign') || "",
#                             "utm_id": getQueryParam('utm_id') || "",
#                             "p1": getQueryParam('p1') || "",
#                             "p2": getQueryParam('p2') || "",
#                             "p3": getQueryParam('p3') || "",
#                             "p4": getQueryParam('p4') || "",
#                             "p5": getQueryParam('p5') || "",
#                             "p6": getQueryParam('p6') || "",
#                             "p7": getQueryParam('p7') || "",
#                             "p8": getQueryParam('p8') || "",
#                             "p9": getQueryParam('p9') || "",
#                     },
#                     "firstPageFlag": isFirstPageVisited(),
#                     "internalCampaign": getQueryParamWithKey("intcmp"),
#                     "siteSection2": secondSegment,
#                     "siteSection3": thirdSegment,
#                     "pageType": templateName,
#                     "domain": cleanUrl(window.location.host),
#                     "siteLanguage": "en",
#                     "pageName": "Homepage",
#                     "siteCountry": "us"
#         };
#
#         if (journeyStep) {
#             pageObj.journeyStep = journeyStep;
#         }
#
#         adobeDataLayer.push({
#             "event": "pageLoad",
#             "_ibm": {
#                 "page": pageObj,
#
#                 "siteActivity": {
#                     "visitDepth": getVisitDepth()
#         	    },
#                 "timeParting": {
#                     "t_AmPM": getAmPm(),
#                     "t_Day": getCurrentDay(),
#                     "t_DayOfMonth": getDayOfMonth(),
#                     "t_DayOfWeek": getDayOfWeekAsInteger(),
#                     "t_DayOfYear": getDayOfYear(),
#                     "t_Hour": getCurrentHour(),
#  		            "t_HourOfDay": getCurrentHourInADay(),
#                     "t_Minute": getCurrentMinute(),
#                     "t_Month": getCurrentMonth(),
#                     "t_MonthOfYear": printCurrentMonthName(),
#                     "t_Quarter": getQuarter(date = new Date()),
#                     "t_QuarterOfYear": getCurrentQuarter(),
#                     "t_Week": getCurrentWeek(),
#                     "t_Weekday_Weekend": getDayType(),
#                     "t_Year": getCurrentYear()
#         	    }
#
#             },
#             paidMediaPlatforms: pmpItems.platforms || [],
#             "web": {
#                 "webPageDetails": {
#                     "pageViews": { "value": 1 },
#                     "URL": document.URL,
#                     "name": cleanUrl(window.location.host) + " | " + templateName + " | Homepage",
#                     "siteSection": firstSegment
#                 },
#                 "webReferrer": {
#                     "URL": document.referrer
#                 }
#             }
#         });
#
#
#
#         var firstH1 = document.querySelector("h1");
#         if (firstH1) {
#                 var h1Content = firstH1.textContent.trim();
#                 window.digitalData.page.taxonomy.pageHeading=h1Content;
#         }
#     });
# </script>
# <script src="/iiONKZJHxoC55gDwgwlu/EDObhfmtLmfhfwOab9/YyZNWVcPAQ/A2BM/Yzs0EQkC" type="text/javascript"></script><link href="/iiONKZJHxoC55gDwgwlu/8cObau/Wj47WVcPAQ/IUMd/eEErSg1Z" rel="stylesheet" type="text/css"/><script async="" defer="" src="/iiONKZJHxoC55gDwgwlu/8cObau/Wj47WVcPAQ/VH0Z/TRwxdX0p"></script><div id="sec-overlay" style="display:none;"><div id="sec-container"></div></div></body>
# </html>

# %%
for link in soup.find_all('a', href = True):
  print(link.get('href'))
# Out:
# https://www.ibm.com/software/data-management?lnk=hpls1us
# https://www.ibm.com/solutions/hybrid-cloud?lnk=hpls2us
# https://www.ibm.com/quantum/blog/international-year-of-quantum?lnk=hprc1us
# https://www.redhat.com/en/about/press-releases/red-hat-nvidia-pair-enterprise-open-source-rack-scale-ai-faster-production-ready-innovation?lnk=hprc2us
# https://www.ibm.com/think/ai-agents?lnk=hprc3us
# https://www.ibm.com/new/product-blog/the-ai-factory-an-enterprise-transformation-engine?lnk=hprc4us
# https://www.ibm.com/case-studies/scuderia-ferrari?lnk=hpcs1us
# https://www.ibm.com/case-studies/avid-solutions-international?lnk=hpcs2us
# https://www.ibm.com/case-studies/pfizer?lnk=hpcs3us
# https://www.ibm.com/case-studies/us-open?lnk=hpcs4us
# https://www.ibm.com/products/offers-and-discounts?lnk=hpdo1us
# https://www.ibm.com/software?lnk=hpfp1us
# https://www.ibm.com/software/ai-productivity?lnk=hpfp2us
# https://www.ibm.com/software/data-management?lnk=hpfp3us
# https://www.ibm.com/software/security-governance?lnk=hpfp4us
# https://www.ibm.com/software/integration-resilience?lnk=hpfp5us
# https://www.ibm.com/software/hybrid-infrastructure-management?lnk=hpfp6us
# https://www.ibm.com/solutions/ai-models?lnk=hpfp7us
# https://www.ibm.com/solutions/analytics?lnk=hpfp8us
# https://www.ibm.com/consulting?lnk=hpfp9us
# https://www.ibm.com/about?lnk=hpii1us
# https://www.ibm.com/history?lnk=hpii1us
# https://research.ibm.com?lnk=hpii1us
# https://www.ibm.com/quantum?lnk=hpii1us
# https://www.ibm.com/careers?lnk=hpii1us
# https://skillsbuild.org?lnk=hpii1us
# https://newsroom.ibm.com/2026-03-18-ibm-fellow-and-quantum-pioneer-charles-h-bennett-receives-a-m-turing-award-computings-highest-honor
# https://newsroom.ibm.com/2026-03-17-ibm-completes-acquisition-of-confluent,-making-real-time-data-the-engine-of-enterprise-ai-and-agents
# https://newsroom.ibm.com/2026-03-16-ibm-and-nvidia-announce-expanded-collaboration-at-gtc-2026-to-advance-ai-for-the-enterprise
# https://newsroom.ibm.com/2026-03-12-ibm-releases-a-new-blueprint-for-quantum-centric-supercomputing
# https://newsroom.ibm.com/2026-03-09-sei-engages-ibm-to-accelerate-enterprise-transformation-through-agentic-ai
# https://newsroom.ibm.com/2026-03-05-ibm-and-university-researchers-create-a-never-before-seen-molecule-and-prove-its-exotic-nature-with-quantum-computing
# https://newsroom.ibm.com/2026-02-25-ibm-awarded-defense-commissary-agency-contract-to-modernize-electronic-shelf-label-system
# https://newsroom.ibm.com/2026-03-10-ibm-and-lam-research-announce-collaboration-to-advance-sub-1nm-logic-scaling

# %%
for link in soup.find_all('img'):
  print(link)
  print(link.get('src'))
# Out:
# <img alt="Abstract representation of computing system" class="cmp-image__image" height="2501" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/compute_iso_still_master_1x1b?ts=1773652275315&amp;dpr=off" srcset="..." width="2501"/>
# https://assets.ibm.com/is/image/ibm/compute_iso_still_master_1x1b?ts=1773652275315&dpr=off
# <img alt="An abstract representation of Red Hat integration" class="cmp-image__image" height="2345" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/redhat_top_still_master_1x1b?ts=1773652276943&amp;dpr=off" srcset="..." title="Abstract Data Visualization with Circular Interface Element" width="2345"/>
# https://assets.ibm.com/is/image/ibm/redhat_top_still_master_1x1b?ts=1773652276943&dpr=off
# <img alt="An abstract representation of AI strategy" class="cmp-image__image" height="1920" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/12_ai_strategy_plan_iso-1x1-b?ts=1773652300920&amp;dpr=off" srcset="..." title="Futuristic device with circular interface" width="1920"/>
# https://assets.ibm.com/is/image/ibm/12_ai_strategy_plan_iso-1x1-b?ts=1773652300920&dpr=off
# <img alt="An abstract representation of tech management" class="cmp-image__image" height="1920" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/15_techmanage_iso-1x1-b?ts=1773652312786&amp;dpr=off" srcset="..." title="Futuristic data device with blue disc" width="1920"/>
# https://assets.ibm.com/is/image/ibm/15_techmanage_iso-1x1-b?ts=1773652312786&dpr=off
# <img alt="Ferrari logo" class="cmp-image__image" height="1920" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/ferrari-shield-transparent?ts=1773652340613&amp;dpr=off" srcset="..." title="Ferrari emblem with prancing horse design" width="3840"/>
# https://assets.ibm.com/is/image/ibm/ferrari-shield-transparent?ts=1773652340613&dpr=off
# <img alt="Avid Solutions logo" class="cmp-image__image" height="160" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/avid-solutions?ts=1773652344512&amp;dpr=off" srcset="..." title="Avid Solutions Text with Orange Feather Graphic" width="320"/>
# https://assets.ibm.com/is/image/ibm/avid-solutions?ts=1773652344512&dpr=off
# <img alt="Pfizer logo" class="cmp-image__image" height="2591" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/pfizer_logo-1?ts=1773652348456&amp;dpr=off" srcset="..." width="6276"/>
# https://assets.ibm.com/is/image/ibm/pfizer_logo-1?ts=1773652348456&dpr=off
# <img alt="US Open logo" class="cmp-image__image" height="501" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/us-open-logo-2-1-v2-no-margin?ts=1773652352245&amp;dpr=off" srcset="..." title="US Open Tennis Tournament Yellow Ball Logo" width="1002"/>
# https://assets.ibm.com/is/image/ibm/us-open-logo-2-1-v2-no-margin?ts=1773652352245&dpr=off
# <img alt="2026 Scuderia Ferrari HP Formula 1 race car, rear view" class="cmp-image__image" height="3840" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/f678_still_f06_v10_zyn_4096x4096?ts=1773652340091&amp;dpr=off" srcset="..." title="Rear view of Formula 1 race car with IBM logo" width="3840"/>
# https://assets.ibm.com/is/image/ibm/f678_still_f06_v10_zyn_4096x4096?ts=1773652340091&dpr=off
# <img alt="Female looking over plants with Avid Solutions logo" class="cmp-image__image" height="1468" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/avid-solutions-leadspace?ts=1773652344045&amp;dpr=off" srcset="..." title="Indoor hydroponic garden with lush greenery" width="3840"/>
# https://assets.ibm.com/is/image/ibm/avid-solutions-leadspace?ts=1773652344045&dpr=off
# <img alt="Pfizer + IBM logos over 3d render of blue molecules" class="cmp-image__image" height="2160" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/pfizer_thumb?ts=1773652347926&amp;dpr=off" srcset="..." title="Pfizer and IBM collaboration visual concept" width="3840"/>
# https://assets.ibm.com/is/image/ibm/pfizer_thumb?ts=1773652347926&dpr=off
# <img alt="Editorial photography supplied by USTA. Provide photo credit: Photo © Dustin Satloff | USTA" class="cmp-image__image" height="1667" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/ashe-day-1-dustin-satloff_usta-2500pxw?ts=1773652351766&amp;dpr=off" srcset="..." title="Crowded tennis stadium during live match" width="2500"/>
# https://assets.ibm.com/is/image/ibm/ashe-day-1-dustin-satloff_usta-2500pxw?ts=1773652351766&dpr=off
# <img alt="Blue illustration with a shopping bag representing IBM offerings and discounts" class="cmp-image__image" height="2161" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/big-blue-30-shopping-promotion-banner?ts=1773678576174&amp;dpr=off" srcset="..." width="3840"/>
# https://assets.ibm.com/is/image/ibm/big-blue-30-shopping-promotion-banner?ts=1773678576174&dpr=off
# <img alt="Illustration of an eye with connecting lines to data" class="cmp-image__image" height="2961" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/watson-discovery_eye-connection_1x1_padding?ts=1773652334244&amp;dpr=off" srcset="..." width="2961"/>
# https://assets.ibm.com/is/image/ibm/watson-discovery_eye-connection_1x1_padding?ts=1773652334244&dpr=off

# %%
#The below url contains an html table with data about colors and color codes.
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %%
soup = BeautifulSoup(data, 'html.parser')

# %%
table = soup.find('table')

# %%
#Get all rows from the table
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].string # store the value in column 3 as color_name
    color_code = cols[3].string # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->None
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF
