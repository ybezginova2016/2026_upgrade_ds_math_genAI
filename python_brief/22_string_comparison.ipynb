# %%
"""
ASCII Table - Complete ASCII code chart with characters.
Also, it contains decimal, hexadecimal, binary, and HTML values.

https://ascii-tables.com/
"""

print('J' < 'Г')
# Out:
# True

# %%
"""
Выведите две введённые строки в лексикографическом порядке через запятую и пробел.
При сравнении букв в разных регистрах меньшей считается буква в верхнем регистре
"""
s1 = input()
s2 = input()

if s1 > s2:
    print(f'{s2}, {s1}')
else:
    print(f'{s1}, {s2}')
# Out:
# Больше, меньше

# %%
first = 90
second = 6

first = second
second = first

# %%
print(first)
print(second)
# Out:
# 6
# 6
