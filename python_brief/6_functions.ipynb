# %% [markdown]
# ## Built-In Functions

# %%
string_length = len("Hello, World!")  # Output: 13
list_length = len([1, 2, 3, 4, 5])   # Output: 5

# %%
total = sum([10, 20, 30, 40, 50])  # Output: 150
total
# Out:
# 150

# %%
highest = max([5, 12, 8, 23, 16])  # Output: 23
highest
# Out:
# 23

# %%
lowest = min([5, 12, 8, 23, 16])  # Output: 5
lowest
# Out:
# 5

# %% [markdown]
# ## Defining your functions

# %%
album_ratings = [10.0, 8.5, 9.5]

# %%
def printStuff(Stuff):
    for i, s in enumerate(Stuff):
        print('Album', i, 'Rating is ', s)

# %%
printStuff(album_ratings)
# Out:
# Album 0 Rating is  10.0
# Album 1 Rating is  8.5
# Album 2 Rating is  9.5

# %%
def NoWork():
    pass
print(NoWork())
# Out:
# None

# %%
def NoWork():
    pass
    return None

# %%
def ArtistNames(*names): # функция может принять любое количество аргументов.
    for name in names:
        print(name)

# %%
ArtistNames('Yulia', 'Zach')
# Out:
# Yulia
# Zach

# %%
ArtistNames('Yulia', 'Zach', 'Italy')
# Out:
# Yulia
# Zach
# Italy

# %% [markdown]
# ## Global Scope

# %%
def AddDC(x):
    x = x + 'DC'
    print(x)
    return x

# %%
x = 'AC'
z = AddDC(x)
# Out:
# ACDC

# %% [markdown]
# ## Scope: Local Variables

# %%
def Thriller():
    Date = 1982
    return Date

# %%
Thriller()
# Out:
# 1982

# %%
Date = 2017

# %%
print(Thriller()) # return value of the local scope
# Out:
# 1982

# %%
print(Date)
# Out:
# 2017

# %%
def PinkFloyd():
    global ClaimedSales
    # внутри функции мы работаем не с локальной переменной, а с глобальной
    # Без global переменная создалась бы только внутри функции
    ClaimedSales = '45 million'
    return ClaimedSales

# %%
PinkFloyd()
# Out:
# '45 million'

# %%
print(ClaimedSales) # переменная ClaimedSales будет доступна и вне функции
# Out:
# 45 million

# %%
def calculate_total(a, b):  # Parameters: a and b
    total = a + b           # Task: Addition
    return total            # Output: Sum of a and b

# %%
result = calculate_total(5, 7)  # Calling the function with inputs 5 and 7

# %%
print(result)  # Output: 12
# Out:
# 12

# %%
"""
A "pass" statement in a programming function is a placeholder or a no-op (no operation) statement. Use it when you want to define a function or a code block syntactically but do not want to specify any functionality or implementation at that moment.
"""

def function_name():
    pass

# %%
def greet(name):
    return "Hello, " + name

# %%
result = greet("Alice")
print(result)  # Output: Hello, Alice
# Out:
# Hello, Alice

# %%
def multiply(a, b):
    """
    This function multiplies two numbers.
    Input: a (number), b (number)
    Output: Product of a and b
    """
    print(a * b)

# %%
multiply(2,6)
# Out:
# 12

# %%
def add(a, b):
    return a + b

# %%
sum_result = add(3, 5)  # sum_result gets the value 8
sum_result
# Out:
# 8

# %%
def greet(name):
    return "Hello, " + name
for _ in range(3):
    print(greet("Alice"))
# Out:
# Hello, Alice
# Hello, Alice
# Hello, Alice

# %%
# Function to remove an element from the list
def remove_element(data_structure, element):
    if element in data_structure:
        data_structure.remove(element)
    else:
        print(f"{element} not found in the list.")

# %%
# Define an empty list as the initial data structure
my_list = []

# %%
# Function to add an element to the list
def add_element(data_structure, element):
    data_structure.append(element)

# %%
# Add elements to the list using the add_element function
add_element(my_list, 42)
add_element(my_list, 17)
add_element(my_list, 99)

# %%
my_list
# Out:
# [42, 17, 99]

# %% [markdown]
# Write a function code to find total count of word `little` in the given string:
# `"Mary had a little lamb Little lamb, little lamb Mary had a little lamb.Its fleece was white as snow And everywhere that Mary went Mary went, Mary went Everywhere that Mary went The lamb was sure to go"**`

# %%
# Python Program to Count words in a String using Dictionary
def freq(string,passedkey):

    #step1: A list variable is declared and initialized to an empty list.
    words = []

    #step2: Break the string into list of words
    words = string.split() # or string.lower().split()

    #step3: Declare a dictionary
    Dict = {}

    #step4: Use for loop to iterate words and values to the dictionary
    for key in words:
        if(key == passedkey):
            Dict[key] = words.count(key)
    #step5: Print the dictionary
    print("Total Count:",Dict)

#step6: Call function and pass string in it
freq("Mary had a little lamb Little lamb, little lamb Mary had a little lamb.Its fleece was white as snow And everywhere that Mary went Mary went, Mary went \
Everywhere that Mary went The lamb was sure to go","little")
# Out:
# Total Count: {'little': 3}

# %%
def count_little(text):
    return text.lower().count("little")

# %%
text = "Mary had a little lamb Little lamb, little lamb Mary had a little lamb.Its fleece was white as snow And everywhere that Mary went Mary went, Mary went Everywhere that Mary went The lamb was sure to go"

# %%
print(count_little(text))
# Out:
# 4

# %%
"little lamb little".count("little")
# Out:
# 2

# %%
text = " Hello World "

print(text.lower())      # " hello world "
print(text.upper())      # " HELLO WORLD "
print(text.strip())      # "Hello World"
print(text.replace("World", "Python"))  # " Hello Python "
print(text.split())      # ["Hello", "World"]
# Out:
#  hello world
#  HELLO WORLD
# Hello World
#  Hello Python
# ['Hello', 'World']

# %%
len(['A','B',1])
# Out:
# 3

# %%
len([sum([1,1,1])])
# Out:
# 1

# %%
L=[1,3,2]

sorted(L)
# Out:
# [1, 2, 3]

# %%
def print_function(A):
    for a in A:
        print(a + '1')
print_function(['a', 'b', 'c'])
# Out:
# a1
# b1
# c1

# %%
"""
Напишите функцию clean_payments, которая принимает список строк.

Каждая строка — это либо число (сумма заказа), либо текстовая ошибка (например, "cancelled", "n/a", "unknown"). Функция должна вернуть кортеж из двух чисел: (сумма успешных оплат, количество ошибок).

Считывать данные и выводить результат не нужно. Проверка пройдет автоматически.
"""

def clean_payments(payments) -> tuple:

    pass

# %%
def clean_payments(payments) -> tuple:
    total = 0
    errors = 0

    for p in payments:
        try:
            total += float(p)
        except ValueError:
            errors += 1

    return (total, errors)
