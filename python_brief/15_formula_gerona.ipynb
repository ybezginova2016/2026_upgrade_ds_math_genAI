# %%
a = int(input())
b = int(input())
c = int(input())

p = (a + b + c) / 2
s = (p * (p - a) * (p - b) * (p - c)) ** 0.5

print(p)
print(s)
# Out:
# 2767.0
# (4.4825518801262717e-10+7320562.766745806j)
