# %%
"""
Пользователь вводит число. Если оно кратно трём, то к нему нужно прибавить 10, а если не кратно, то вычесть 5.
"""

n = int(input())
result = n + int(n % 3 == 0) * 10 - int(n % 3 != 0) * 5
print(result)
# Out:
# 44

# %%
"""
Напишите программу, которая найдёт и выведет чётное число, ближайшее сверху к введённому пользователем.

Это значит, что если пользователь ввёл нечётное число, то вывести нужно следующее — большее на 1; если же введено чётное число, то вывести нужно большее на 2.
"""

a = 5

# %%
if a % 2 == 0:
    b = a + 2
    print(b)
elif a % 2 != 0:
    b = a + 1
    print(b)
# Out:
# 6

# %%
print(a + 2 if a % 2 == 0 else a + 1)
# Out:
# 6

# %%
print(a + 1 + int(a % 2 == 0))
# Out:
# 6

# %%
number = 1564

digit_1 = number // 1000
digit_2 = number // 100 % 10
digit_3 = number // 10 % 10
digit_4 = number % 10

digits_sum = digit_1 + digit_2 + digit_3 + digit_4
found = False

if digits_sum % digit_1 == 0:
    print(f'Сумма цифр {number} делится на {digit_1}')
    found = True

if digits_sum % digit_2 == 0:
    print(f'Сумма цифр {number} делится на {digit_2}')
    found = True

if digits_sum % digit_3 == 0:
    print(f'Сумма цифр {number} делится на {digit_3}')
    found = True

if digits_sum % digit_4 == 0:
    print(f'Сумма цифр {number} делится на {digit_4}')
    found = True

if not found:
    print(f'Сумма цифр {number} не делится на свои цифры.')
# Out:
# Сумма цифр 1564 делится на 1
# Сумма цифр 1564 делится на 4

# %%
n = int(input())
if n % 3 == 0:
   n = n // 3
elif n % 2 == 0:
   n = n // 2
else:
   n = n - 1
print(n)
# Out:
# 4
