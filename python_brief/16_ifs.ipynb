# %%
import sys


def main():
    turn = sys.stdin.read().strip()

    if turn.lower() == 'налево':
        sys.stdout.write('Туда')
    else:
        sys.stdout.write('Не туда')


if __name__ == '__main__':
    main()
# Out:
# Не туда

# %%
i = input().strip()

if i == 'налево':
    print('Туда')
else:
    print('Не туда')
# Out:
# Не туда
