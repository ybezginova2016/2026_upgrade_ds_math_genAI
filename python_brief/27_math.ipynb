# %%
from math import degrees as dg
from math import pi
import math as mt

# %%
n = dg(3.14) # перевести угол 3.14 из радиан в градусы
print(n)
# Out:
# 179.9087476710785

# %%
n = mt.sqrt(16)
print(n)
# Out:
# 4.0

# %%
print(dg(pi))  # 180.0
# Out:
# 180.0
